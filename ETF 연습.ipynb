# %%
import pandas as pd
import numpy as np
import requests

# %%
url =  'https://finance.naver.com/api/sise/etfItemList.nhn'
print(url)
# Out:
# https://finance.naver.com/api/sise/etfItemList.nhn

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
etf_json = response.json()
etf_json
# Out:
# {'resultCode': 'success',
#  'result': {'etfItemList': [{'itemcode': '069500',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200',
#     'nowVal': 43640,
#     'risefall': '5',
#     'changeVal': -255,
#     'changeRate': -0.58,
#     'nav': 43745.0,
#     'threeMonthEarnRate': 5.3977,
#     'quant': 3117261,
#     'amonut': 136125,
#     'marketSum': 40782},
#    {'itemcode': '153130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권',
#     'nowVal': 102775,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 102779.0,
#     'threeMonthEarnRate': 0.0048,
#     'quant': 2394,
#     'amonut': 246,
#     'marketSum': 24889},
#    {'itemcode': '252670',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 200선물인버스2X',
#     'nowVal': 1875,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 1.35,
#     'nav': 1876.0,
#     'threeMonthEarnRate': -11.4833,
#     'quant': 105541555,
#     'amonut': 197354,
#     'marketSum': 24881},
#    {'itemcode': '102110',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 200',
#     'nowVal': 43665,
#     'risefall': '5',
#     'changeVal': -250,
#     'changeRate': -0.57,
#     'nav': 43771.0,
#     'threeMonthEarnRate': 5.342,
#     'quant': 608535,
#     'amonut': 26593,
#     'marketSum': 21767},
#    {'itemcode': '102780',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 삼성그룹',
#     'nowVal': 10365,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.63,
#     'nav': 10378.0,
#     'threeMonthEarnRate': 4.114,
#     'quant': 321065,
#     'amonut': 3322,
#     'marketSum': 18958},
#    {'itemcode': '214980',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권PLUS',
#     'nowVal': 103065,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 103062.0,
#     'threeMonthEarnRate': 0.0339,
#     'quant': 425026,
#     'amonut': 43803,
#     'marketSum': 16390},
#    {'itemcode': '273130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 종합채권(AA-이상)액티브',
#     'nowVal': 108635,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.06,
#     'nav': 108579.0,
#     'threeMonthEarnRate': -0.1426,
#     'quant': 15636,
#     'amonut': 1699,
#     'marketSum': 14344},
#    {'itemcode': '278530',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200TR',
#     'nowVal': 14280,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -0.73,
#     'nav': 14305.0,
#     'threeMonthEarnRate': 5.5005,
#     'quant': 44969,
#     'amonut': 641,
#     'marketSum': 14266},
#    {'itemcode': '122630',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 레버리지',
#     'nowVal': 28925,
#     'risefall': '5',
#     'changeVal': -375,
#     'changeRate': -1.28,
#     'nav': 29179.0,
#     'threeMonthEarnRate': 10.3993,
#     'quant': 12082878,
#     'amonut': 350083,
#     'marketSum': 14000},
#    {'itemcode': '305720',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 2차전지산업',
#     'nowVal': 19260,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.13,
#     'nav': 19269.0,
#     'threeMonthEarnRate': 9.4701,
#     'quant': 2007018,
#     'amonut': 38777,
#     'marketSum': 12846},
#    {'itemcode': '148020',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 200',
#     'nowVal': 43675,
#     'risefall': '5',
#     'changeVal': -245,
#     'changeRate': -0.56,
#     'nav': 43779.0,
#     'threeMonthEarnRate': 5.2909,
#     'quant': 164837,
#     'amonut': 7199,
#     'marketSum': 11967},
#    {'itemcode': '278540',
#     'etfTabCode': 1,
#     'itemname': 'KODEX MSCI Korea TR',
#     'nowVal': 14010,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -0.67,
#     'nav': 14034.0,
#     'threeMonthEarnRate': 4.1728,
#     'quant': 321676,
#     'amonut': 4520,
#     'marketSum': 11698},
#    {'itemcode': '114800',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 인버스',
#     'nowVal': 3710,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.82,
#     'nav': 3709.0,
#     'threeMonthEarnRate': -5.8824,
#     'quant': 13726794,
#     'amonut': 50806,
#     'marketSum': 11635},
#    {'itemcode': '233740',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스닥150 레버리지',
#     'nowVal': 15525,
#     'risefall': '2',
#     'changeVal': 210,
#     'changeRate': 1.37,
#     'nav': 15729.0,
#     'threeMonthEarnRate': 4.0421,
#     'quant': 6973058,
#     'amonut': 107645,
#     'marketSum': 10184},
#    {'itemcode': '371460',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나전기차SOLACTIVE',
#     'nowVal': 14595,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.34,
#     'nav': None,
#     'threeMonthEarnRate': 37.8019,
#     'quant': 1943473,
#     'amonut': 28329,
#     'marketSum': 10106},
#    {'itemcode': '292150',
#     'etfTabCode': 2,
#     'itemname': 'TIGER TOP10',
#     'nowVal': 15070,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -0.56,
#     'nav': 15078.0,
#     'threeMonthEarnRate': 4.4452,
#     'quant': 302630,
#     'amonut': 4563,
#     'marketSum': 9848},
#    {'itemcode': '157450',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기통안채',
#     'nowVal': 100185,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 100186.0,
#     'threeMonthEarnRate': 0.0499,
#     'quant': 1068,
#     'amonut': 106,
#     'marketSum': 9512},
#    {'itemcode': '139260',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 IT',
#     'nowVal': 38805,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.01,
#     'nav': 38822.0,
#     'threeMonthEarnRate': 0.9415,
#     'quant': 123937,
#     'amonut': 4806,
#     'marketSum': 9259},
#    {'itemcode': '305540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 2차전지테마',
#     'nowVal': 18470,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.24,
#     'nav': 18471.0,
#     'threeMonthEarnRate': 12.2461,
#     'quant': 736526,
#     'amonut': 13614,
#     'marketSum': 8736},
#    {'itemcode': '152100',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200',
#     'nowVal': 44040,
#     'risefall': '5',
#     'changeVal': -380,
#     'changeRate': -0.86,
#     'nav': 44146.0,
#     'threeMonthEarnRate': 5.7165,
#     'quant': 214674,
#     'amonut': 9454,
#     'marketSum': 8654},
#    {'itemcode': '364980',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX2차전지K-뉴딜',
#     'nowVal': 17050,
#     'risefall': '5',
#     'changeVal': -180,
#     'changeRate': -1.04,
#     'nav': 17041.0,
#     'threeMonthEarnRate': 12.3207,
#     'quant': 1591109,
#     'amonut': 27454,
#     'marketSum': 8005},
#    {'itemcode': '133690',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국나스닥100',
#     'nowVal': 73980,
#     'risefall': '2',
#     'changeVal': 330,
#     'changeRate': 0.45,
#     'nav': None,
#     'threeMonthEarnRate': 12.2302,
#     'quant': 61573,
#     'amonut': 4554,
#     'marketSum': 7768},
#    {'itemcode': '105190',
#     'etfTabCode': 1,
#     'itemname': 'KINDEX 200',
#     'nowVal': 43695,
#     'risefall': '5',
#     'changeVal': -400,
#     'changeRate': -0.91,
#     'nav': 43818.0,
#     'threeMonthEarnRate': 5.6091,
#     'quant': 414081,
#     'amonut': 18085,
#     'marketSum': 7472},
#    {'itemcode': '310970',
#     'etfTabCode': 1,
#     'itemname': 'TIGER MSCI Korea TR',
#     'nowVal': 17645,
#     'risefall': '5',
#     'changeVal': -120,
#     'changeRate': -0.68,
#     'nav': 17628.0,
#     'threeMonthEarnRate': 3.8281,
#     'quant': 2146,
#     'amonut': 37,
#     'marketSum': 7323},
#    {'itemcode': '293180',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200',
#     'nowVal': 43610,
#     'risefall': '5',
#     'changeVal': -395,
#     'changeRate': -0.9,
#     'nav': 43739.0,
#     'threeMonthEarnRate': 5.525,
#     'quant': 112747,
#     'amonut': 4928,
#     'marketSum': 6302},
#    {'itemcode': '229200',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스닥 150',
#     'nowVal': 14680,
#     'risefall': '2',
#     'changeVal': 105,
#     'changeRate': 0.72,
#     'nav': 14823.0,
#     'threeMonthEarnRate': 2.1731,
#     'quant': 1623918,
#     'amonut': 23747,
#     'marketSum': 5967},
#    {'itemcode': '069660',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200',
#     'nowVal': 43625,
#     'risefall': '5',
#     'changeVal': -405,
#     'changeRate': -0.92,
#     'nav': 43733.0,
#     'threeMonthEarnRate': 5.6863,
#     'quant': 2109,
#     'amonut': 92,
#     'marketSum': 5868},
#    {'itemcode': '314250',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국FANG플러스(H)',
#     'nowVal': 28905,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -0.21,
#     'nav': None,
#     'threeMonthEarnRate': 14.7583,
#     'quant': 246931,
#     'amonut': 7135,
#     'marketSum': 5824},
#    {'itemcode': '091180',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 자동차',
#     'nowVal': 24845,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.14,
#     'nav': 24833.0,
#     'threeMonthEarnRate': 7.2493,
#     'quant': 587265,
#     'amonut': 14459,
#     'marketSum': 5429},
#    {'itemcode': '315930',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Top5PlusTR',
#     'nowVal': 20065,
#     'risefall': '5',
#     'changeVal': -230,
#     'changeRate': -1.13,
#     'nav': 20041.0,
#     'threeMonthEarnRate': 2.6036,
#     'quant': 4227,
#     'amonut': 84,
#     'marketSum': 5217},
#    {'itemcode': '294400',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200TR',
#     'nowVal': 51845,
#     'risefall': '5',
#     'changeVal': -475,
#     'changeRate': -0.91,
#     'nav': 51974.0,
#     'threeMonthEarnRate': 5.7183,
#     'quant': 4397,
#     'amonut': 228,
#     'marketSum': 5029},
#    {'itemcode': '364960',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX BBIG K-뉴딜',
#     'nowVal': 13365,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.49,
#     'nav': 13362.0,
#     'threeMonthEarnRate': 10.8333,
#     'quant': 780149,
#     'amonut': 10433,
#     'marketSum': 4999},
#    {'itemcode': '295040',
#     'etfTabCode': 1,
#     'itemname': 'SMART 200TR',
#     'nowVal': 14850,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.47,
#     'nav': 14884.0,
#     'threeMonthEarnRate': 5.2928,
#     'quant': 4027,
#     'amonut': 59,
#     'marketSum': 4544},
#    {'itemcode': '251340',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 코스닥150선물인버스',
#     'nowVal': 4360,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.57,
#     'nav': 4355.0,
#     'threeMonthEarnRate': -4.1531,
#     'quant': 25416475,
#     'amonut': 111211,
#     'marketSum': 4238},
#    {'itemcode': '360750',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500',
#     'nowVal': 12310,
#     'risefall': '2',
#     'changeVal': 100,
#     'changeRate': 0.82,
#     'nav': None,
#     'threeMonthEarnRate': 7.615,
#     'quant': 299098,
#     'amonut': 3677,
#     'marketSum': 3595},
#    {'itemcode': '385540',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS종합채권(A-이상)액티브',
#     'nowVal': 100000,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.02,
#     'nav': 100048.0,
#     'threeMonthEarnRate': None,
#     'quant': 42,
#     'amonut': 4,
#     'marketSum': 3491},
#    {'itemcode': '226490',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스피',
#     'nowVal': 32920,
#     'risefall': '5',
#     'changeVal': -235,
#     'changeRate': -0.71,
#     'nav': 33019.0,
#     'threeMonthEarnRate': 7.6495,
#     'quant': 46831,
#     'amonut': 1546,
#     'marketSum': 3490},
#    {'itemcode': '332500',
#     'etfTabCode': 1,
#     'itemname': 'KINDEX 200TR',
#     'nowVal': 26600,
#     'risefall': '5',
#     'changeVal': -225,
#     'changeRate': -0.84,
#     'nav': 26658.0,
#     'threeMonthEarnRate': 5.4441,
#     'quant': 646,
#     'amonut': 17,
#     'marketSum': 3405},
#    {'itemcode': '381180',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국필라델피아반도체나스닥',
#     'nowVal': 10215,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.34,
#     'nav': None,
#     'threeMonthEarnRate': None,
#     'quant': 791425,
#     'amonut': 8080,
#     'marketSum': 3340},
#    {'itemcode': '290130',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR ESG사회책임투자',
#     'nowVal': 14230,
#     'risefall': '5',
#     'changeVal': -115,
#     'changeRate': -0.8,
#     'nav': 14260.0,
#     'threeMonthEarnRate': 4.9992,
#     'quant': 129687,
#     'amonut': 1845,
#     'marketSum': 3244},
#    {'itemcode': '357870',
#     'etfTabCode': 7,
#     'itemname': 'TIGER CD금리투자KIS(합성)',
#     'nowVal': 50340,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 50342.0,
#     'threeMonthEarnRate': 0.1791,
#     'quant': 50,
#     'amonut': 2,
#     'marketSum': 3154},
#    {'itemcode': '192090',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300',
#     'nowVal': 12090,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.33,
#     'nav': None,
#     'threeMonthEarnRate': 4.2838,
#     'quant': 337942,
#     'amonut': 4087,
#     'marketSum': 3071},
#    {'itemcode': '282000',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 국고채3년선물인버스',
#     'nowVal': 100085,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100132.0,
#     'threeMonthEarnRate': 0.3609,
#     'quant': 42,
#     'amonut': 4,
#     'marketSum': 3036},
#    {'itemcode': '251350',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 선진국MSCI World',
#     'nowVal': 19200,
#     'risefall': '2',
#     'changeVal': 90,
#     'changeRate': 0.47,
#     'nav': None,
#     'threeMonthEarnRate': 6.5514,
#     'quant': 126890,
#     'amonut': 2429,
#     'marketSum': 2880},
#    {'itemcode': '332940',
#     'etfTabCode': 1,
#     'itemname': 'HANARO MSCI Korea TR',
#     'nowVal': 17550,
#     'risefall': '5',
#     'changeVal': -180,
#     'changeRate': -1.02,
#     'nav': 17604.0,
#     'threeMonthEarnRate': 3.9577,
#     'quant': 50,
#     'amonut': 0,
#     'marketSum': 2843},
#    {'itemcode': '091170',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 은행',
#     'nowVal': 7585,
#     'risefall': '5',
#     'changeVal': -80,
#     'changeRate': -1.04,
#     'nav': 7574.0,
#     'threeMonthEarnRate': 10.4148,
#     'quant': 1272872,
#     'amonut': 9657,
#     'marketSum': 2799},
#    {'itemcode': '275980',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#     'nowVal': 18755,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -0.32,
#     'nav': None,
#     'threeMonthEarnRate': 7.9151,
#     'quant': 91035,
#     'amonut': 1705,
#     'marketSum': 2738},
#    {'itemcode': '367770',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn수소경제테마',
#     'nowVal': 12870,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.19,
#     'nav': 12888.0,
#     'threeMonthEarnRate': 1.2961,
#     'quant': 148488,
#     'amonut': 1906,
#     'marketSum': 2735},
#    {'itemcode': '091160',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 반도체',
#     'nowVal': 38220,
#     'risefall': '5',
#     'changeVal': -305,
#     'changeRate': -0.79,
#     'nav': 38301.0,
#     'threeMonthEarnRate': 5.8815,
#     'quant': 148074,
#     'amonut': 5678,
#     'marketSum': 2695},
#    {'itemcode': '168580',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 중국본토CSI300',
#     'nowVal': 32405,
#     'risefall': '2',
#     'changeVal': 175,
#     'changeRate': 0.54,
#     'nav': None,
#     'threeMonthEarnRate': 4.4732,
#     'quant': 13788,
#     'amonut': 447,
#     'marketSum': 2592},
#    {'itemcode': '261220',
#     'etfTabCode': 5,
#     'itemname': 'KODEX WTI원유선물(H)',
#     'nowVal': 11080,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.45,
#     'nav': None,
#     'threeMonthEarnRate': 19.3722,
#     'quant': 381617,
#     'amonut': 4222,
#     'marketSum': 2535},
#    {'itemcode': '190620',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 단기통안채',
#     'nowVal': 100315,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 100311.0,
#     'threeMonthEarnRate': 0.0748,
#     'quant': 741,
#     'amonut': 74,
#     'marketSum': 2522},
#    {'itemcode': '385550',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS단기종합채권(AA-이상)액티브',
#     'nowVal': 99865,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.01,
#     'nav': 99873.0,
#     'threeMonthEarnRate': None,
#     'quant': 42,
#     'amonut': 4,
#     'marketSum': 2502},
#    {'itemcode': '272580',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기채권액티브',
#     'nowVal': 50060,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 50062.0,
#     'threeMonthEarnRate': -0.04,
#     'quant': 4583,
#     'amonut': 229,
#     'marketSum': 2417},
#    {'itemcode': '360200',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국S&P500',
#     'nowVal': 12395,
#     'risefall': '2',
#     'changeVal': 105,
#     'changeRate': 0.85,
#     'nav': None,
#     'threeMonthEarnRate': 7.7503,
#     'quant': 143612,
#     'amonut': 1777,
#     'marketSum': 2405},
#    {'itemcode': '132030',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 골드선물(H)',
#     'nowVal': 12070,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 1.09,
#     'nav': None,
#     'threeMonthEarnRate': 2.7096,
#     'quant': 299713,
#     'amonut': 3605,
#     'marketSum': 2402},
#    {'itemcode': '143850',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500선물(H)',
#     'nowVal': 50175,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 0.26,
#     'nav': None,
#     'threeMonthEarnRate': 8.2639,
#     'quant': 44268,
#     'amonut': 2220,
#     'marketSum': 2358},
#    {'itemcode': '371160',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나항셍테크',
#     'nowVal': 10390,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 0.92,
#     'nav': None,
#     'threeMonthEarnRate': -0.6275,
#     'quant': 209820,
#     'amonut': 2166,
#     'marketSum': 2317},
#    {'itemcode': '196230',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기통안채',
#     'nowVal': 104430,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.01,
#     'nav': 104432.0,
#     'threeMonthEarnRate': 0.0622,
#     'quant': 578275,
#     'amonut': 60388,
#     'marketSum': 2289},
#    {'itemcode': '272560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기국공채액티브',
#     'nowVal': 101990,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': 0.0,
#     'nav': 101992.0,
#     'threeMonthEarnRate': 0.0981,
#     'quant': 801486,
#     'amonut': 81747,
#     'marketSum': 2270},
#    {'itemcode': '332930',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200TR',
#     'nowVal': 51890,
#     'risefall': '5',
#     'changeVal': -450,
#     'changeRate': -0.86,
#     'nav': 52001.0,
#     'threeMonthEarnRate': 5.6093,
#     'quant': 2081,
#     'amonut': 107,
#     'marketSum': 2257},
#    {'itemcode': '232080',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스닥150',
#     'nowVal': 14890,
#     'risefall': '2',
#     'changeVal': 115,
#     'changeRate': 0.78,
#     'nav': 15031.0,
#     'threeMonthEarnRate': 2.2137,
#     'quant': 455267,
#     'amonut': 6762,
#     'marketSum': 2183},
#    {'itemcode': '245710',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 베트남VN30(합성)',
#     'nowVal': 22405,
#     'risefall': '2',
#     'changeVal': 280,
#     'changeRate': 1.27,
#     'nav': None,
#     'threeMonthEarnRate': 29.5374,
#     'quant': 94924,
#     'amonut': 2117,
#     'marketSum': 2106},
#    {'itemcode': '381170',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국테크TOP10 INDXX',
#     'nowVal': 10750,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.33,
#     'nav': None,
#     'threeMonthEarnRate': None,
#     'quant': 590150,
#     'amonut': 6334,
#     'marketSum': 2053},
#    {'itemcode': '161510',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 고배당주',
#     'nowVal': 12560,
#     'risefall': '5',
#     'changeVal': -120,
#     'changeRate': -0.95,
#     'nav': 12563.0,
#     'threeMonthEarnRate': 11.355,
#     'quant': 134936,
#     'amonut': 1698,
#     'marketSum': 1922},
#    {'itemcode': '302450',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스피',
#     'nowVal': 33030,
#     'risefall': '5',
#     'changeVal': -120,
#     'changeRate': -0.36,
#     'nav': 33004.0,
#     'threeMonthEarnRate': 6.9941,
#     'quant': 107,
#     'amonut': 3,
#     'marketSum': 1916},
#    {'itemcode': '278240',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150선물레버리지',
#     'nowVal': 15800,
#     'risefall': '2',
#     'changeVal': 200,
#     'changeRate': 1.28,
#     'nav': 15880.0,
#     'threeMonthEarnRate': 4.7683,
#     'quant': 73152,
#     'amonut': 1151,
#     'marketSum': 1901},
#    {'itemcode': '267770',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 200선물레버리지',
#     'nowVal': 21815,
#     'risefall': '5',
#     'changeVal': -320,
#     'changeRate': -1.45,
#     'nav': 21850.0,
#     'threeMonthEarnRate': 11.008,
#     'quant': 830189,
#     'amonut': 18130,
#     'marketSum': 1832},
#    {'itemcode': '270810',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150',
#     'nowVal': 14535,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.59,
#     'nav': 14696.0,
#     'threeMonthEarnRate': 2.1201,
#     'quant': 10864,
#     'amonut': 157,
#     'marketSum': 1704},
#    {'itemcode': '150460',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 중국소비테마',
#     'nowVal': 9330,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.21,
#     'nav': 9346.0,
#     'threeMonthEarnRate': 14.1496,
#     'quant': 54797,
#     'amonut': 510,
#     'marketSum': 1702},
#    {'itemcode': '367380',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국나스닥100',
#     'nowVal': 12700,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.47,
#     'nav': None,
#     'threeMonthEarnRate': 12.2458,
#     'quant': 86621,
#     'amonut': 1099,
#     'marketSum': 1651},
#    {'itemcode': '143860',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 헬스케어',
#     'nowVal': 45515,
#     'risefall': '2',
#     'changeVal': 780,
#     'changeRate': 1.74,
#     'nav': 45703.0,
#     'threeMonthEarnRate': -1.584,
#     'quant': 58676,
#     'amonut': 2655,
#     'marketSum': 1557},
#    {'itemcode': '326240',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR IT플러스',
#     'nowVal': 22760,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.04,
#     'nav': 22773.0,
#     'threeMonthEarnRate': 7.6697,
#     'quant': 296444,
#     'amonut': 6753,
#     'marketSum': 1552},
#    {'itemcode': '091230',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 반도체',
#     'nowVal': 39220,
#     'risefall': '5',
#     'changeVal': -175,
#     'changeRate': -0.44,
#     'nav': 39218.0,
#     'threeMonthEarnRate': 5.6392,
#     'quant': 59629,
#     'amonut': 2339,
#     'marketSum': 1490},
#    {'itemcode': '108450',
#     'etfTabCode': 2,
#     'itemname': 'KINDEX 삼성그룹섹터가중',
#     'nowVal': 17090,
#     'risefall': '2',
#     'changeVal': 90,
#     'changeRate': 0.53,
#     'nav': 17136.0,
#     'threeMonthEarnRate': 6.8107,
#     'quant': 2110,
#     'amonut': 36,
#     'marketSum': 1470},
#    {'itemcode': '148070',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 국고채10년',
#     'nowVal': 120435,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.03,
#     'nav': 120403.0,
#     'threeMonthEarnRate': 0.1872,
#     'quant': 4263,
#     'amonut': 513,
#     'marketSum': 1469},
#    {'itemcode': '298770',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 한국대만IT프리미어',
#     'nowVal': 20325,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.07,
#     'nav': None,
#     'threeMonthEarnRate': 1.2967,
#     'quant': 21221,
#     'amonut': 430,
#     'marketSum': 1443},
#    {'itemcode': '138540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 현대차그룹+펀더멘털',
#     'nowVal': 28530,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.16,
#     'nav': 28546.0,
#     'threeMonthEarnRate': 8.8944,
#     'quant': 72968,
#     'amonut': 2071,
#     'marketSum': 1369},
#    {'itemcode': '182480',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 미국MSCI리츠(합성 H)',
#     'nowVal': 14655,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.24,
#     'nav': None,
#     'threeMonthEarnRate': 10.9851,
#     'quant': 67557,
#     'amonut': 989,
#     'marketSum': 1363},
#    {'itemcode': '204480',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300레버리지(합성)',
#     'nowVal': 33480,
#     'risefall': '2',
#     'changeVal': 410,
#     'changeRate': 1.24,
#     'nav': None,
#     'threeMonthEarnRate': 6.1296,
#     'quant': 95895,
#     'amonut': 3199,
#     'marketSum': 1272},
#    {'itemcode': '283580',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 중국본토CSI300',
#     'nowVal': 14685,
#     'risefall': '2',
#     'changeVal': 110,
#     'changeRate': 0.75,
#     'nav': None,
#     'threeMonthEarnRate': 4.3307,
#     'quant': 145843,
#     'amonut': 2137,
#     'marketSum': 1263},
#    {'itemcode': '219480',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500선물(H)',
#     'nowVal': 20650,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.27,
#     'nav': None,
#     'threeMonthEarnRate': 8.3377,
#     'quant': 264755,
#     'amonut': 5468,
#     'marketSum': 1260},
#    {'itemcode': '328370',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 코스피TR',
#     'nowVal': 16475,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -0.51,
#     'nav': 16475.0,
#     'threeMonthEarnRate': 7.2191,
#     'quant': 37,
#     'amonut': 0,
#     'marketSum': 1244},
#    {'itemcode': '372330',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나항셍테크',
#     'nowVal': 10410,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.77,
#     'nav': None,
#     'threeMonthEarnRate': -0.7209,
#     'quant': 114314,
#     'amonut': 1184,
#     'marketSum': 1228},
#    {'itemcode': '367760',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn5G테크',
#     'nowVal': 11555,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.22,
#     'nav': 11555.0,
#     'threeMonthEarnRate': 1.5878,
#     'quant': 130031,
#     'amonut': 1502,
#     'marketSum': 1219},
#    {'itemcode': '252710',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 200선물인버스2X',
#     'nowVal': 1945,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 1.57,
#     'nav': 1946.0,
#     'threeMonthEarnRate': -11.5474,
#     'quant': 2284776,
#     'amonut': 4436,
#     'marketSum': 1216},
#    {'itemcode': '136340',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 중기우량회사채',
#     'nowVal': 104975,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.03,
#     'nav': 104937.0,
#     'threeMonthEarnRate': -0.1617,
#     'quant': 671,
#     'amonut': 70,
#     'marketSum': 1197},
#    {'itemcode': '273140',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기변동금리부채권액티브',
#     'nowVal': 102555,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 102561.0,
#     'threeMonthEarnRate': 0.0683,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 1139},
#    {'itemcode': '233160',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스닥150 레버리지',
#     'nowVal': 16490,
#     'risefall': '2',
#     'changeVal': 205,
#     'changeRate': 1.26,
#     'nav': 16713.0,
#     'threeMonthEarnRate': 3.8915,
#     'quant': 863894,
#     'amonut': 14200,
#     'marketSum': 1113},
#    {'itemcode': '139280',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 경기방어',
#     'nowVal': 12780,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.04,
#     'nav': 12776.0,
#     'threeMonthEarnRate': 2.249,
#     'quant': 19404,
#     'amonut': 246,
#     'marketSum': 1109},
#    {'itemcode': '329200',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 부동산인프라고배당',
#     'nowVal': 5925,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.34,
#     'nav': 5947.0,
#     'threeMonthEarnRate': 13.4325,
#     'quant': 158382,
#     'amonut': 939,
#     'marketSum': 1081},
#    {'itemcode': '390950',
#     'etfTabCode': 6,
#     'itemname': 'HANARO 단기채권액티브',
#     'nowVal': 100040,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100038.0,
#     'threeMonthEarnRate': None,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 1069},
#    {'itemcode': '325010',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Fn성장',
#     'nowVal': 19025,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.24,
#     'nav': 18999.0,
#     'threeMonthEarnRate': 4.9128,
#     'quant': 1189,
#     'amonut': 22,
#     'marketSum': 1065},
#    {'itemcode': '225040',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500레버리지(합성 H)',
#     'nowVal': 31640,
#     'risefall': '2',
#     'changeVal': 120,
#     'changeRate': 0.38,
#     'nav': None,
#     'threeMonthEarnRate': 16.1171,
#     'quant': 4797,
#     'amonut': 151,
#     'marketSum': 1044},
#    {'itemcode': '176950',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국채선물10년인버스',
#     'nowVal': 47180,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.06,
#     'nav': 47215.0,
#     'threeMonthEarnRate': -0.2747,
#     'quant': 46,
#     'amonut': 2,
#     'marketSum': 1042},
#    {'itemcode': '144600',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 은선물(H)',
#     'nowVal': 5425,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 1.59,
#     'nav': None,
#     'threeMonthEarnRate': 4.3988,
#     'quant': 320589,
#     'amonut': 1734,
#     'marketSum': 1042},
#    {'itemcode': '156080',
#     'etfTabCode': 1,
#     'itemname': 'KODEX MSCI Korea',
#     'nowVal': 20415,
#     'risefall': '5',
#     'changeVal': -125,
#     'changeRate': -0.61,
#     'nav': 20436.0,
#     'threeMonthEarnRate': 3.7321,
#     'quant': 224,
#     'amonut': 4,
#     'marketSum': 1021},
#    {'itemcode': '325020',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 배당가치',
#     'nowVal': 13825,
#     'risefall': '5',
#     'changeVal': -140,
#     'changeRate': -1.0,
#     'nav': 13807.0,
#     'threeMonthEarnRate': 7.7629,
#     'quant': 6470,
#     'amonut': 89,
#     'marketSum': 995},
#    {'itemcode': '376410',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 탄소효율그린뉴딜',
#     'nowVal': 10495,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.43,
#     'nav': 10504.0,
#     'threeMonthEarnRate': 5.6112,
#     'quant': 12669,
#     'amonut': 132,
#     'marketSum': 976},
#    {'itemcode': '228800',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 여행레저',
#     'nowVal': 5330,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.74,
#     'nav': 5309.0,
#     'threeMonthEarnRate': 13.1717,
#     'quant': 402987,
#     'amonut': 2154,
#     'marketSum': 956},
#    {'itemcode': '117700',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 건설',
#     'nowVal': 3890,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.64,
#     'nav': 3902.0,
#     'threeMonthEarnRate': 17.1103,
#     'quant': 571371,
#     'amonut': 2226,
#     'marketSum': 945},
#    {'itemcode': '114260',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채3년',
#     'nowVal': 57845,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.11,
#     'nav': 57827.0,
#     'threeMonthEarnRate': -0.302,
#     'quant': 37695,
#     'amonut': 2181,
#     'marketSum': 937},
#    {'itemcode': '371470',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나바이오테크SOLACTIVE',
#     'nowVal': 13455,
#     'risefall': '2',
#     'changeVal': 120,
#     'changeRate': 0.9,
#     'nav': None,
#     'threeMonthEarnRate': 15.8557,
#     'quant': 65862,
#     'amonut': 883,
#     'marketSum': 931},
#    {'itemcode': '368190',
#     'etfTabCode': 2,
#     'itemname': 'HANARO Fn K-뉴딜디지털플러스',
#     'nowVal': 13610,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.11,
#     'nav': 13616.0,
#     'threeMonthEarnRate': 9.3938,
#     'quant': 98691,
#     'amonut': 1347,
#     'marketSum': 925},
#    {'itemcode': '364970',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX바이오K-뉴딜',
#     'nowVal': 10725,
#     'risefall': '2',
#     'changeVal': 215,
#     'changeRate': 2.05,
#     'nav': 10723.0,
#     'threeMonthEarnRate': 1.0091,
#     'quant': 375965,
#     'amonut': 3979,
#     'marketSum': 879},
#    {'itemcode': '368590',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국나스닥100',
#     'nowVal': 12300,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.49,
#     'nav': None,
#     'threeMonthEarnRate': 12.242,
#     'quant': 78213,
#     'amonut': 961,
#     'marketSum': 873},
#    {'itemcode': '195930',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 유로스탁스50(합성 H)',
#     'nowVal': 13865,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -0.61,
#     'nav': None,
#     'threeMonthEarnRate': 5.9627,
#     'quant': 94994,
#     'amonut': 1313,
#     'marketSum': 818},
#    {'itemcode': '130680',
#     'etfTabCode': 5,
#     'itemname': 'TIGER 원유선물Enhanced(H)',
#     'nowVal': 3335,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.15,
#     'nav': None,
#     'threeMonthEarnRate': 19.5691,
#     'quant': 277703,
#     'amonut': 925,
#     'marketSum': 785},
#    {'itemcode': '174360',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 중국본토대형주CSI100',
#     'nowVal': 22270,
#     'risefall': '2',
#     'changeVal': 240,
#     'changeRate': 1.09,
#     'nav': None,
#     'threeMonthEarnRate': 0.7546,
#     'quant': 20914,
#     'amonut': 464,
#     'marketSum': 779},
#    {'itemcode': '309230',
#     'etfTabCode': 2,
#     'itemname': 'KINDEX 미국WideMoat가치주',
#     'nowVal': 16885,
#     'risefall': '2',
#     'changeVal': 105,
#     'changeRate': 0.63,
#     'nav': None,
#     'threeMonthEarnRate': 5.5677,
#     'quant': 46142,
#     'amonut': 778,
#     'marketSum': 777},
#    {'itemcode': '256750',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 심천ChiNext(합성)',
#     'nowVal': 14795,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.44,
#     'nav': None,
#     'threeMonthEarnRate': 22.8011,
#     'quant': 117892,
#     'amonut': 1738,
#     'marketSum': 769},
#    {'itemcode': '195980',
#     'etfTabCode': 4,
#     'itemname': 'ARIRANG 신흥국MSCI(합성 H)',
#     'nowVal': 13160,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.08,
#     'nav': None,
#     'threeMonthEarnRate': 3.6657,
#     'quant': 33681,
#     'amonut': 442,
#     'marketSum': 745},
#    {'itemcode': '266160',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 고배당',
#     'nowVal': 12875,
#     'risefall': '5',
#     'changeVal': -150,
#     'changeRate': -1.15,
#     'nav': 12880.0,
#     'threeMonthEarnRate': 8.0823,
#     'quant': 69163,
#     'amonut': 892,
#     'marketSum': 740},
#    {'itemcode': '261240',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물',
#     'nowVal': 10040,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.55,
#     'nav': 10045.0,
#     'threeMonthEarnRate': -0.6962,
#     'quant': 89244,
#     'amonut': 894,
#     'marketSum': 735},
#    {'itemcode': '304940',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100선물(H)',
#     'nowVal': 18475,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.11,
#     'nav': None,
#     'threeMonthEarnRate': 12.7743,
#     'quant': 261749,
#     'amonut': 4836,
#     'marketSum': 730},
#    {'itemcode': '123310',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 인버스',
#     'nowVal': 4095,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.49,
#     'nav': 4101.0,
#     'threeMonthEarnRate': -5.6713,
#     'quant': 105473,
#     'amonut': 431,
#     'marketSum': 729},
#    {'itemcode': '385520',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-미래차액티브',
#     'nowVal': 11080,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.31,
#     'nav': 11096.0,
#     'threeMonthEarnRate': None,
#     'quant': 350310,
#     'amonut': 3863,
#     'marketSum': 726},
#    {'itemcode': '139220',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 건설',
#     'nowVal': 3380,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 3377.0,
#     'threeMonthEarnRate': 17.036,
#     'quant': 1007061,
#     'amonut': 3406,
#     'marketSum': 694},
#    {'itemcode': '157490',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 소프트웨어',
#     'nowVal': 19565,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.18,
#     'nav': 19569.0,
#     'threeMonthEarnRate': 18.2561,
#     'quant': 155273,
#     'amonut': 3049,
#     'marketSum': 689},
#    {'itemcode': '277630',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스피',
#     'nowVal': 33315,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -0.18,
#     'nav': 33317.0,
#     'threeMonthEarnRate': 7.3772,
#     'quant': 485,
#     'amonut': 16,
#     'marketSum': 666},
#    {'itemcode': '245360',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나HSCEI',
#     'nowVal': 12745,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -0.66,
#     'nav': None,
#     'threeMonthEarnRate': -1.9488,
#     'quant': 7827,
#     'amonut': 100,
#     'marketSum': 663},
#    {'itemcode': '114820',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 국채3년',
#     'nowVal': 110265,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 110248.0,
#     'threeMonthEarnRate': -0.2037,
#     'quant': 469,
#     'amonut': 51,
#     'marketSum': 662},
#    {'itemcode': '289260',
#     'etfTabCode': 2,
#     'itemname': 'TIGER MSCI KOREA ESG리더스',
#     'nowVal': 12350,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -0.76,
#     'nav': 12398.0,
#     'threeMonthEarnRate': 5.4303,
#     'quant': 1646,
#     'amonut': 20,
#     'marketSum': 652},
#    {'itemcode': '385560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS국고채30년Enhanced',
#     'nowVal': 102485,
#     'risefall': '2',
#     'changeVal': 685,
#     'changeRate': 0.67,
#     'nav': 102694.0,
#     'threeMonthEarnRate': None,
#     'quant': 43,
#     'amonut': 4,
#     'marketSum': 646},
#    {'itemcode': '363510',
#     'etfTabCode': 6,
#     'itemname': 'SMART KIS단기통안채',
#     'nowVal': 100320,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100323.0,
#     'threeMonthEarnRate': 0.0648,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 636},
#    {'itemcode': '306520',
#     'etfTabCode': 3,
#     'itemname': 'HANARO 200선물인버스',
#     'nowVal': 8535,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.59,
#     'nav': 8530.0,
#     'threeMonthEarnRate': -5.407,
#     'quant': 719,
#     'amonut': 6,
#     'marketSum': 632},
#    {'itemcode': '379800',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500TR',
#     'nowVal': 10725,
#     'risefall': '2',
#     'changeVal': 90,
#     'changeRate': 0.85,
#     'nav': None,
#     'threeMonthEarnRate': None,
#     'quant': 110550,
#     'amonut': 1184,
#     'marketSum': 622},
#    {'itemcode': '117680',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 철강',
#     'nowVal': 10170,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.88,
#     'nav': 10190.0,
#     'threeMonthEarnRate': 18.5715,
#     'quant': 211063,
#     'amonut': 2147,
#     'marketSum': 619},
#    {'itemcode': '245340',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국다우존스30',
#     'nowVal': 19795,
#     'risefall': '2',
#     'changeVal': 240,
#     'changeRate': 1.23,
#     'nav': None,
#     'threeMonthEarnRate': 3.0566,
#     'quant': 25284,
#     'amonut': 499,
#     'marketSum': 614},
#    {'itemcode': '336160',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 금융채액티브',
#     'nowVal': 102800,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.05,
#     'nav': 102795.0,
#     'threeMonthEarnRate': -0.3102,
#     'quant': 46,
#     'amonut': 4,
#     'marketSum': 596},
#    {'itemcode': '315960',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 대형고배당10TR',
#     'nowVal': 17335,
#     'risefall': '5',
#     'changeVal': -210,
#     'changeRate': -1.2,
#     'nav': 17314.0,
#     'threeMonthEarnRate': 2.4226,
#     'quant': 6127,
#     'amonut': 106,
#     'marketSum': 589},
#    {'itemcode': '102970',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 증권',
#     'nowVal': 8450,
#     'risefall': '5',
#     'changeVal': -135,
#     'changeRate': -1.57,
#     'nav': 8450.0,
#     'threeMonthEarnRate': 11.8566,
#     'quant': 295829,
#     'amonut': 2509,
#     'marketSum': 583},
#    {'itemcode': '361580',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 200TR',
#     'nowVal': 22340,
#     'risefall': '5',
#     'changeVal': -160,
#     'changeRate': -0.71,
#     'nav': 22381.0,
#     'threeMonthEarnRate': 5.5347,
#     'quant': 967,
#     'amonut': 21,
#     'marketSum': 581},
#    {'itemcode': '139230',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 중공업',
#     'nowVal': 3850,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.39,
#     'nav': 3864.0,
#     'threeMonthEarnRate': 19.2901,
#     'quant': 299151,
#     'amonut': 1151,
#     'marketSum': 576},
#    {'itemcode': '387280',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 퓨처모빌리티액티브',
#     'nowVal': 10710,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.28,
#     'nav': 10742.0,
#     'threeMonthEarnRate': None,
#     'quant': 815772,
#     'amonut': 8746,
#     'marketSum': 571},
#    {'itemcode': '304780',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200선물레버리지',
#     'nowVal': 31710,
#     'risefall': '5',
#     'changeVal': -440,
#     'changeRate': -1.37,
#     'nav': 31724.0,
#     'threeMonthEarnRate': 10.6903,
#     'quant': 2838,
#     'amonut': 90,
#     'marketSum': 571},
#    {'itemcode': '329750',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국달러단기채권액티브',
#     'nowVal': 9710,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.36,
#     'nav': None,
#     'threeMonthEarnRate': -0.463,
#     'quant': 118708,
#     'amonut': 1151,
#     'marketSum': 552},
#    {'itemcode': '219390',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국S&P원유생산기업(합성 H)',
#     'nowVal': 4395,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 2.21,
#     'nav': None,
#     'threeMonthEarnRate': 18.7845,
#     'quant': 299164,
#     'amonut': 1310,
#     'marketSum': 549},
#    {'itemcode': '337140',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 코스피대형주',
#     'nowVal': 15435,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.45,
#     'nav': 15430.0,
#     'threeMonthEarnRate': 5.8578,
#     'quant': 13127,
#     'amonut': 202,
#     'marketSum': 540},
#    {'itemcode': '363580',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 200IT TR',
#     'nowVal': 14590,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.34,
#     'nav': 14644.0,
#     'threeMonthEarnRate': 1.1398,
#     'quant': 3747,
#     'amonut': 54,
#     'marketSum': 540},
#    {'itemcode': '305080',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국채10년선물',
#     'nowVal': 11610,
#     'risefall': '2',
#     'changeVal': 90,
#     'changeRate': 0.78,
#     'nav': None,
#     'threeMonthEarnRate': 0.9198,
#     'quant': 30830,
#     'amonut': 357,
#     'marketSum': 534},
#    {'itemcode': '130730',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 단기자금',
#     'nowVal': 101060,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.01,
#     'nav': 101052.0,
#     'threeMonthEarnRate': 0.0594,
#     'quant': 874224,
#     'amonut': 88344,
#     'marketSum': 532},
#    {'itemcode': '266370',
#     'etfTabCode': 2,
#     'itemname': 'KODEX IT',
#     'nowVal': 21175,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.12,
#     'nav': 21212.0,
#     'threeMonthEarnRate': 0.1373,
#     'quant': 40721,
#     'amonut': 863,
#     'marketSum': 529},
#    {'itemcode': '322400',
#     'etfTabCode': 2,
#     'itemname': 'HANARO e커머스',
#     'nowVal': 20730,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -0.41,
#     'nav': 20734.0,
#     'threeMonthEarnRate': 22.8385,
#     'quant': 182250,
#     'amonut': 3788,
#     'marketSum': 529},
#    {'itemcode': '375770',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 탄소효율그린뉴딜',
#     'nowVal': 10450,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.62,
#     'nav': 10485.0,
#     'threeMonthEarnRate': 5.5722,
#     'quant': 2873,
#     'amonut': 30,
#     'marketSum': 523},
#    {'itemcode': '371450',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌클라우드컴퓨팅INDXX',
#     'nowVal': 11400,
#     'risefall': '5',
#     'changeVal': -125,
#     'changeRate': -1.08,
#     'nav': None,
#     'threeMonthEarnRate': 14.0524,
#     'quant': 44259,
#     'amonut': 504,
#     'marketSum': 511},
#    {'itemcode': '243880',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200IT레버리지',
#     'nowVal': 68000,
#     'risefall': '5',
#     'changeVal': -250,
#     'changeRate': -0.37,
#     'nav': 68385.0,
#     'threeMonthEarnRate': 2.3852,
#     'quant': 3447,
#     'amonut': 234,
#     'marketSum': 510},
#    {'itemcode': '310960',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 200TR',
#     'nowVal': 23255,
#     'risefall': '5',
#     'changeVal': -155,
#     'changeRate': -0.66,
#     'nav': 23306.0,
#     'threeMonthEarnRate': 5.3555,
#     'quant': 1150,
#     'amonut': 26,
#     'marketSum': 488},
#    {'itemcode': '292190',
#     'etfTabCode': 1,
#     'itemname': 'KODEX KRX300',
#     'nowVal': 20065,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.45,
#     'nav': 20068.0,
#     'threeMonthEarnRate': 4.9684,
#     'quant': 4440,
#     'amonut': 89,
#     'marketSum': 482},
#    {'itemcode': '228810',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 미디어컨텐츠',
#     'nowVal': 8375,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.36,
#     'nav': 8380.0,
#     'threeMonthEarnRate': 17.4524,
#     'quant': 223868,
#     'amonut': 1872,
#     'marketSum': 480},
#    {'itemcode': '302190',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 중장기국채',
#     'nowVal': 52160,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.06,
#     'nav': 52154.0,
#     'threeMonthEarnRate': -0.0576,
#     'quant': 7948,
#     'amonut': 414,
#     'marketSum': 480},
#    {'itemcode': '379810',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100TR',
#     'nowVal': 10860,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.42,
#     'nav': None,
#     'threeMonthEarnRate': None,
#     'quant': 219258,
#     'amonut': 2381,
#     'marketSum': 467},
#    {'itemcode': '329650',
#     'etfTabCode': 7,
#     'itemname': 'KODEX TRF3070',
#     'nowVal': 11220,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.18,
#     'nav': 11170.0,
#     'threeMonthEarnRate': 1.9108,
#     'quant': 57118,
#     'amonut': 640,
#     'marketSum': 460},
#    {'itemcode': '266360',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 미디어&엔터테인먼트',
#     'nowVal': 26225,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 0.36,
#     'nav': 26290.0,
#     'threeMonthEarnRate': 20.8044,
#     'quant': 43018,
#     'amonut': 1133,
#     'marketSum': 446},
#    {'itemcode': '365000',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX인터넷K-뉴딜',
#     'nowVal': 13035,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.11,
#     'nav': 13067.0,
#     'threeMonthEarnRate': 16.8307,
#     'quant': 169039,
#     'amonut': 2214,
#     'marketSum': 417},
#    {'itemcode': '114460',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국고채3년',
#     'nowVal': 106330,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.01,
#     'nav': 106307.0,
#     'threeMonthEarnRate': -0.244,
#     'quant': 544,
#     'amonut': 57,
#     'marketSum': 415},
#    {'itemcode': '272570',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 중장기국공채액티브',
#     'nowVal': 103300,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.02,
#     'nav': 103244.0,
#     'threeMonthEarnRate': -0.1258,
#     'quant': 24,
#     'amonut': 2,
#     'marketSum': 395},
#    {'itemcode': '341850',
#     'etfTabCode': 7,
#     'itemname': 'TIGER KIS부동산인프라채권TR',
#     'nowVal': 5780,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.43,
#     'nav': 5819.0,
#     'threeMonthEarnRate': 8.9322,
#     'quant': 354541,
#     'amonut': 2044,
#     'marketSum': 393},
#    {'itemcode': '256440',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 인도네시아MSCI(합성)',
#     'nowVal': 7785,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.39,
#     'nav': None,
#     'threeMonthEarnRate': -9.0323,
#     'quant': 29273,
#     'amonut': 228,
#     'marketSum': 381},
#    {'itemcode': '356540',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX KIS종합채권(AA-이상)액티브',
#     'nowVal': 98050,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.05,
#     'nav': 98059.0,
#     'threeMonthEarnRate': -0.3559,
#     'quant': 2,
#     'amonut': 0,
#     'marketSum': 377},
#    {'itemcode': '280930',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국러셀2000(H)',
#     'nowVal': 15050,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.57,
#     'nav': None,
#     'threeMonthEarnRate': 5.9094,
#     'quant': 254469,
#     'amonut': 3829,
#     'marketSum': 376},
#    {'itemcode': '304770',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 코스닥150',
#     'nowVal': 14675,
#     'risefall': '2',
#     'changeVal': 120,
#     'changeRate': 0.82,
#     'nav': 14812.0,
#     'threeMonthEarnRate': 2.5,
#     'quant': 8375,
#     'amonut': 122,
#     'marketSum': 373},
#    {'itemcode': '354350',
#     'etfTabCode': 4,
#     'itemname': 'HANARO 글로벌럭셔리S&P(합성)',
#     'nowVal': 18160,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.06,
#     'nav': None,
#     'threeMonthEarnRate': 11.8842,
#     'quant': 54301,
#     'amonut': 984,
#     'marketSum': 372},
#    {'itemcode': '385510',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-신재생에너지액티브',
#     'nowVal': 10305,
#     'risefall': '5',
#     'changeVal': -110,
#     'changeRate': -1.06,
#     'nav': 10340.0,
#     'threeMonthEarnRate': None,
#     'quant': 57584,
#     'amonut': 595,
#     'marketSum': 371},
#    {'itemcode': '122260',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 통안채1년',
#     'nowVal': 101120,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.02,
#     'nav': 101113.0,
#     'threeMonthEarnRate': -0.0989,
#     'quant': 151738,
#     'amonut': 15342,
#     'marketSum': 364},
#    {'itemcode': '244580',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 바이오',
#     'nowVal': 15455,
#     'risefall': '2',
#     'changeVal': 345,
#     'changeRate': 2.28,
#     'nav': 15555.0,
#     'threeMonthEarnRate': 5.0764,
#     'quant': 212523,
#     'amonut': 3247,
#     'marketSum': 359},
#    {'itemcode': '279530',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 고배당',
#     'nowVal': 10150,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.39,
#     'nav': 10163.0,
#     'threeMonthEarnRate': 12.4103,
#     'quant': 43878,
#     'amonut': 445,
#     'marketSum': 355},
#    {'itemcode': '169950',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 중국본토 A50',
#     'nowVal': 23615,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 0.4,
# ...
#     'nowVal': 51150,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.13,
#     'nav': 51177.0,
#     'threeMonthEarnRate': -0.263,
#     'quant': 42,
#     'amonut': 2,
#     'marketSum': 61},
#    {'itemcode': '157500',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 증권',
#     'nowVal': 4940,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -1.4,
#     'nav': 4941.0,
#     'threeMonthEarnRate': 10.8897,
#     'quant': 37949,
#     'amonut': 188,
#     'marketSum': 61},
#    {'itemcode': '346000',
#     'etfTabCode': 6,
#     'itemname': 'HANARO KAP초장기국고채',
#     'nowVal': 46030,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.12,
#     'nav': 46140.0,
#     'threeMonthEarnRate': -0.2907,
#     'quant': 320,
#     'amonut': 14,
#     'marketSum': 61},
#    {'itemcode': '250730',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 차이나HSCEI(H)',
#     'nowVal': 12090,
#     'risefall': '5',
#     'changeVal': -170,
#     'changeRate': -1.39,
#     'nav': None,
#     'threeMonthEarnRate': -2.3886,
#     'quant': 6,
#     'amonut': 0,
#     'marketSum': 60},
#    {'itemcode': '176710',
#     'etfTabCode': 6,
#     'itemname': '파워 중기국고채',
#     'nowVal': 100035,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': 0.0,
#     'nav': 100024.0,
#     'threeMonthEarnRate': -0.2045,
#     'quant': 2,
#     'amonut': 0,
#     'marketSum': 60},
#    {'itemcode': '287310',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200경기소비재',
#     'nowVal': 12450,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.08,
#     'nav': 12470.0,
#     'threeMonthEarnRate': 7.1582,
#     'quant': 2012,
#     'amonut': 24,
#     'marketSum': 60},
#    {'itemcode': '342610',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KRX국채선물3년10년플래트너',
#     'nowVal': 49700,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.02,
#     'nav': 49719.0,
#     'threeMonthEarnRate': 0.3735,
#     'quant': 42,
#     'amonut': 2,
#     'marketSum': 60},
#    {'itemcode': '287320',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200산업재',
#     'nowVal': 13480,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.55,
#     'nav': 13485.0,
#     'threeMonthEarnRate': 17.4508,
#     'quant': 515,
#     'amonut': 6,
#     'marketSum': 59},
#    {'itemcode': '213610',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 삼성그룹밸류',
#     'nowVal': 9860,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 9861.0,
#     'threeMonthEarnRate': 6.25,
#     'quant': 14063,
#     'amonut': 138,
#     'marketSum': 59},
#    {'itemcode': '217790',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 가격조정',
#     'nowVal': 26875,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 0.49,
#     'nav': 26869.0,
#     'threeMonthEarnRate': 2.1425,
#     'quant': 10837,
#     'amonut': 290,
#     'marketSum': 59},
#    {'itemcode': '342620',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KRX국채선물3년10년플래트너2X',
#     'nowVal': 49020,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.02,
#     'nav': 49042.0,
#     'threeMonthEarnRate': 0.6365,
#     'quant': 91,
#     'amonut': 4,
#     'marketSum': 59},
#    {'itemcode': '302180',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 국채선물10년인버스',
#     'nowVal': 48535,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 48543.0,
#     'threeMonthEarnRate': -0.1954,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 58},
#    {'itemcode': '333980',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG KS퀄리티가중TR',
#     'nowVal': 16485,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.18,
#     'nav': 16485.0,
#     'threeMonthEarnRate': 4.9904,
#     'quant': 28,
#     'amonut': 0,
#     'marketSum': 58},
#    {'itemcode': '275750',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150선물인버스',
#     'nowVal': 4595,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.76,
#     'nav': 4594.0,
#     'threeMonthEarnRate': -3.8422,
#     'quant': 14942,
#     'amonut': 68,
#     'marketSum': 57},
#    {'itemcode': '267440',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국장기국채선물(H)',
#     'nowVal': 11465,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.04,
#     'nav': None,
#     'threeMonthEarnRate': 4.7531,
#     'quant': 529,
#     'amonut': 6,
#     'marketSum': 57},
#    {'itemcode': '290080',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200고배당커버드콜ATM',
#     'nowVal': 8160,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.12,
#     'nav': 8140.0,
#     'threeMonthEarnRate': 7.8755,
#     'quant': 136,
#     'amonut': 1,
#     'marketSum': 57},
#    {'itemcode': '280920',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 주도업종',
#     'nowVal': 12630,
#     'risefall': '5',
#     'changeVal': -160,
#     'changeRate': -1.25,
#     'nav': 12631.0,
#     'threeMonthEarnRate': 8.5369,
#     'quant': 993,
#     'amonut': 12,
#     'marketSum': 57},
#    {'itemcode': '269530',
#     'etfTabCode': 4,
#     'itemname': 'ARIRANG S&P글로벌인프라',
#     'nowVal': 11350,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.49,
#     'nav': None,
#     'threeMonthEarnRate': 1.6651,
#     'quant': 1159,
#     'amonut': 13,
#     'marketSum': 57},
#    {'itemcode': '295000',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물10년',
#     'nowVal': 55285,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.03,
#     'nav': 55275.0,
#     'threeMonthEarnRate': 0.281,
#     'quant': 133,
#     'amonut': 7,
#     'marketSum': 56},
#    {'itemcode': '380340',
#     'etfTabCode': 2,
#     'itemname': 'KINDEX Fn5G플러스',
#     'nowVal': 9380,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.21,
#     'nav': 9416.0,
#     'threeMonthEarnRate': None,
#     'quant': 2876,
#     'amonut': 26,
#     'marketSum': 56},
#    {'itemcode': '140570',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 수출주',
#     'nowVal': 13920,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.39,
#     'nav': 13906.0,
#     'threeMonthEarnRate': 10.2912,
#     'quant': 63,
#     'amonut': 0,
#     'marketSum': 56},
#    {'itemcode': '309210',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG KRX300헬스케어',
#     'nowVal': 13905,
#     'risefall': '2',
#     'changeVal': 220,
#     'changeRate': 1.61,
#     'nav': 13984.0,
#     'threeMonthEarnRate': -1.6529,
#     'quant': 2026,
#     'amonut': 27,
#     'marketSum': 56},
#    {'itemcode': '266550',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 중형주저변동50',
#     'nowVal': 12215,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.37,
#     'nav': 12218.0,
#     'threeMonthEarnRate': 9.1135,
#     'quant': 80,
#     'amonut': 0,
#     'marketSum': 55},
#    {'itemcode': '261920',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 필리핀MSCI(합성)',
#     'nowVal': 13725,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.18,
#     'nav': None,
#     'threeMonthEarnRate': 4.1825,
#     'quant': 1744,
#     'amonut': 24,
#     'marketSum': 55},
#    {'itemcode': '278420',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG ESG우수기업',
#     'nowVal': 9980,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.5,
#     'nav': 9991.0,
#     'threeMonthEarnRate': 11.7797,
#     'quant': 2474,
#     'amonut': 24,
#     'marketSum': 55},
#    {'itemcode': '295020',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물10년인버스',
#     'nowVal': 47770,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.08,
#     'nav': 47809.0,
#     'threeMonthEarnRate': -0.1462,
#     'quant': 42,
#     'amonut': 2,
#     'marketSum': 54},
#    {'itemcode': '285010',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200중공업',
#     'nowVal': 11800,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.63,
#     'nav': 11833.0,
#     'threeMonthEarnRate': 19.8647,
#     'quant': 1733,
#     'amonut': 20,
#     'marketSum': 54},
#    {'itemcode': '321410',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 멀티에셋하이인컴(H)',
#     'nowVal': 10835,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.05,
#     'nav': None,
#     'threeMonthEarnRate': 3.9846,
#     'quant': 1319,
#     'amonut': 14,
#     'marketSum': 54},
#    {'itemcode': '304670',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국채울트라30년선물인버스(H)',
#     'nowVal': 7560,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': None,
#     'threeMonthEarnRate': -7.0111,
#     'quant': 5489,
#     'amonut': 41,
#     'marketSum': 53},
#    {'itemcode': '269370',
#     'etfTabCode': 4,
#     'itemname': 'TIGER S&P글로벌인프라(합성)',
#     'nowVal': 10500,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.1,
#     'nav': None,
#     'threeMonthEarnRate': 1.9337,
#     'quant': 316,
#     'amonut': 3,
#     'marketSum': 53},
#    {'itemcode': '220130',
#     'etfTabCode': 4,
#     'itemname': 'SMART 중국본토 중소형 CSI500(합성 H)',
#     'nowVal': 5690,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.09,
#     'nav': None,
#     'threeMonthEarnRate': 9.0124,
#     'quant': 5319,
#     'amonut': 30,
#     'marketSum': 51},
#    {'itemcode': '292770',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국채선물3년인버스',
#     'nowVal': 49925,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 49944.0,
#     'threeMonthEarnRate': 0.3215,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 51},
#    {'itemcode': '371870',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 차이나항셍테크',
#     'nowVal': 10180,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.15,
#     'nav': None,
#     'threeMonthEarnRate': -0.926,
#     'quant': 4594,
#     'amonut': 46,
#     'marketSum': 51},
#    {'itemcode': '261270',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물인버스',
#     'nowVal': 10110,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.49,
#     'nav': 10109.0,
#     'threeMonthEarnRate': 0.594,
#     'quant': 1287,
#     'amonut': 13,
#     'marketSum': 51},
#    {'itemcode': '261260',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물인버스2X',
#     'nowVal': 9675,
#     'risefall': '5',
#     'changeVal': -115,
#     'changeRate': -1.17,
#     'nav': 9676.0,
#     'threeMonthEarnRate': 0.8758,
#     'quant': 33102,
#     'amonut': 320,
#     'marketSum': 50},
#    {'itemcode': '285020',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200철강소재',
#     'nowVal': 9675,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.67,
#     'nav': 9670.0,
#     'threeMonthEarnRate': 15.8971,
#     'quant': 4287,
#     'amonut': 41,
#     'marketSum': 50},
#    {'itemcode': '299080',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국채선물3년인버스',
#     'nowVal': 99795,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.05,
#     'nav': 99870.0,
#     'threeMonthEarnRate': 0.377,
#     'quant': 1,
#     'amonut': 0,
#     'marketSum': 50},
#    {'itemcode': '291680',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 차이나H선물인버스(H)',
#     'nowVal': 9585,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.84,
#     'nav': None,
#     'threeMonthEarnRate': 1.8211,
#     'quant': 104,
#     'amonut': 0,
#     'marketSum': 48},
#    {'itemcode': '299070',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국채선물10년인버스',
#     'nowVal': 95685,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.09,
#     'nav': 95791.0,
#     'threeMonthEarnRate': -0.0209,
#     'quant': 1,
#     'amonut': 0,
#     'marketSum': 48},
#    {'itemcode': '139310',
#     'etfTabCode': 5,
#     'itemname': 'TIGER 금속선물(H)',
#     'nowVal': 6825,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.73,
#     'nav': None,
#     'threeMonthEarnRate': 10.9765,
#     'quant': 12143,
#     'amonut': 83,
#     'marketSum': 48},
#    {'itemcode': '211260',
#     'etfTabCode': 2,
#     'itemname': 'KINDEX 배당성장',
#     'nowVal': 39480,
#     'risefall': '5',
#     'changeVal': -230,
#     'changeRate': -0.58,
#     'nav': 39421.0,
#     'threeMonthEarnRate': 7.7056,
#     'quant': 94,
#     'amonut': 3,
#     'marketSum': 47},
#    {'itemcode': '287330',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200생활소비재',
#     'nowVal': 9315,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.59,
#     'nav': 9322.0,
#     'threeMonthEarnRate': 4.4476,
#     'quant': 15830,
#     'amonut': 147,
#     'marketSum': 47},
#    {'itemcode': '296710',
#     'etfTabCode': 2,
#     'itemname': 'KODEX FnKorea50',
#     'nowVal': 11535,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.43,
#     'nav': 11532.0,
#     'threeMonthEarnRate': 8.1295,
#     'quant': 37,
#     'amonut': 0,
#     'marketSum': 46},
#    {'itemcode': '284980',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200금융',
#     'nowVal': 9110,
#     'risefall': '5',
#     'changeVal': -120,
#     'changeRate': -1.3,
#     'nav': 9117.0,
#     'threeMonthEarnRate': 8.6137,
#     'quant': 5137,
#     'amonut': 46,
#     'marketSum': 46},
#    {'itemcode': '301410',
#     'etfTabCode': 3,
#     'itemname': 'ARIRANG 코스닥150선물인버스',
#     'nowVal': 6920,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.43,
#     'nav': 6889.0,
#     'threeMonthEarnRate': -3.9392,
#     'quant': 7508,
#     'amonut': 52,
#     'marketSum': 45},
#    {'itemcode': '280940',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 골드선물인버스(H)',
#     'nowVal': 7350,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.68,
#     'nav': None,
#     'threeMonthEarnRate': -3.078,
#     'quant': 2427,
#     'amonut': 17,
#     'marketSum': 44},
#    {'itemcode': '227560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 생활소비재',
#     'nowVal': 12230,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.73,
#     'nav': 12234.0,
#     'threeMonthEarnRate': 4.3183,
#     'quant': 2351,
#     'amonut': 28,
#     'marketSum': 44},
#    {'itemcode': '291620',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 코스닥150선물인버스',
#     'nowVal': 7920,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.69,
#     'nav': 7902.0,
#     'threeMonthEarnRate': -3.7998,
#     'quant': 1615,
#     'amonut': 12,
#     'marketSum': 42},
#    {'itemcode': '267450',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국장기국채선물인버스(H)',
#     'nowVal': 8100,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.06,
#     'nav': None,
#     'threeMonthEarnRate': -5.3707,
#     'quant': 2165,
#     'amonut': 17,
#     'marketSum': 41},
#    {'itemcode': '253240',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 200선물인버스',
#     'nowVal': 4805,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.63,
#     'nav': 4795.0,
#     'threeMonthEarnRate': -5.6325,
#     'quant': 13337,
#     'amonut': 63,
#     'marketSum': 39},
#    {'itemcode': '291660',
#     'etfTabCode': 4,
#     'itemname': 'KODEX China H선물인버스(H)',
#     'nowVal': 9680,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.1,
#     'nav': None,
#     'threeMonthEarnRate': 1.7894,
#     'quant': 31,
#     'amonut': 0,
#     'marketSum': 39},
#    {'itemcode': '217770',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 원유선물인버스(H)',
#     'nowVal': 5850,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.51,
#     'nav': None,
#     'threeMonthEarnRate': -17.7623,
#     'quant': 3679,
#     'amonut': 21,
#     'marketSum': 38},
#    {'itemcode': '267500',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#     'nowVal': 6290,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.16,
#     'nav': None,
#     'threeMonthEarnRate': -10.4776,
#     'quant': 7052,
#     'amonut': 44,
#     'marketSum': 35},
#    {'itemcode': '291890',
#     'etfTabCode': 4,
#     'itemname': 'KODEX MSCI EM선물(H)',
#     'nowVal': 11000,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.32,
#     'nav': None,
#     'threeMonthEarnRate': 4.746,
#     'quant': 1220,
#     'amonut': 13,
#     'marketSum': 33},
#    {'itemcode': '309170',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG KRX300IT',
#     'nowVal': 19400,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 19512.0,
#     'threeMonthEarnRate': -0.3391,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 27},
#    {'itemcode': '306540',
#     'etfTabCode': 6,
#     'itemname': 'HANARO 단기통안채',
#     'nowVal': 103070,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 103070.0,
#     'threeMonthEarnRate': 0.0631,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 23},
#    {'itemcode': '334700',
#     'etfTabCode': 5,
#     'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#     'nowVal': 4355,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -2.35,
#     'nav': None,
#     'threeMonthEarnRate': -7.9464,
#     'quant': 3768,
#     'amonut': 16,
#     'marketSum': 22}]}}

# %%
etfItemList = etf_json['result']['etfItemList']
etfItemList
# Out:
# [{'itemcode': '069500',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 200',
#   'nowVal': 43640,
#   'risefall': '5',
#   'changeVal': -255,
#   'changeRate': -0.58,
#   'nav': 43745.0,
#   'threeMonthEarnRate': 5.3977,
#   'quant': 3117261,
#   'amonut': 136125,
#   'marketSum': 40782},
#  {'itemcode': '153130',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 단기채권',
#   'nowVal': 102775,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 102779.0,
#   'threeMonthEarnRate': 0.0048,
#   'quant': 2394,
#   'amonut': 246,
#   'marketSum': 24889},
#  {'itemcode': '252670',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 200선물인버스2X',
#   'nowVal': 1875,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 1.35,
#   'nav': 1876.0,
#   'threeMonthEarnRate': -11.4833,
#   'quant': 105541555,
#   'amonut': 197354,
#   'marketSum': 24881},
#  {'itemcode': '102110',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 200',
#   'nowVal': 43665,
#   'risefall': '5',
#   'changeVal': -250,
#   'changeRate': -0.57,
#   'nav': 43771.0,
#   'threeMonthEarnRate': 5.342,
#   'quant': 608535,
#   'amonut': 26593,
#   'marketSum': 21767},
#  {'itemcode': '102780',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 삼성그룹',
#   'nowVal': 10365,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.63,
#   'nav': 10378.0,
#   'threeMonthEarnRate': 4.114,
#   'quant': 321065,
#   'amonut': 3322,
#   'marketSum': 18958},
#  {'itemcode': '214980',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 단기채권PLUS',
#   'nowVal': 103065,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 103062.0,
#   'threeMonthEarnRate': 0.0339,
#   'quant': 425026,
#   'amonut': 43803,
#   'marketSum': 16390},
#  {'itemcode': '273130',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 종합채권(AA-이상)액티브',
#   'nowVal': 108635,
#   'risefall': '2',
#   'changeVal': 70,
#   'changeRate': 0.06,
#   'nav': 108579.0,
#   'threeMonthEarnRate': -0.1426,
#   'quant': 15636,
#   'amonut': 1699,
#   'marketSum': 14344},
#  {'itemcode': '278530',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 200TR',
#   'nowVal': 14280,
#   'risefall': '5',
#   'changeVal': -105,
#   'changeRate': -0.73,
#   'nav': 14305.0,
#   'threeMonthEarnRate': 5.5005,
#   'quant': 44969,
#   'amonut': 641,
#   'marketSum': 14266},
#  {'itemcode': '122630',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 레버리지',
#   'nowVal': 28925,
#   'risefall': '5',
#   'changeVal': -375,
#   'changeRate': -1.28,
#   'nav': 29179.0,
#   'threeMonthEarnRate': 10.3993,
#   'quant': 12082878,
#   'amonut': 350083,
#   'marketSum': 14000},
#  {'itemcode': '305720',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 2차전지산업',
#   'nowVal': 19260,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.13,
#   'nav': 19269.0,
#   'threeMonthEarnRate': 9.4701,
#   'quant': 2007018,
#   'amonut': 38777,
#   'marketSum': 12846},
#  {'itemcode': '148020',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 200',
#   'nowVal': 43675,
#   'risefall': '5',
#   'changeVal': -245,
#   'changeRate': -0.56,
#   'nav': 43779.0,
#   'threeMonthEarnRate': 5.2909,
#   'quant': 164837,
#   'amonut': 7199,
#   'marketSum': 11967},
#  {'itemcode': '278540',
#   'etfTabCode': 1,
#   'itemname': 'KODEX MSCI Korea TR',
#   'nowVal': 14010,
#   'risefall': '5',
#   'changeVal': -95,
#   'changeRate': -0.67,
#   'nav': 14034.0,
#   'threeMonthEarnRate': 4.1728,
#   'quant': 321676,
#   'amonut': 4520,
#   'marketSum': 11698},
#  {'itemcode': '114800',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 인버스',
#   'nowVal': 3710,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.82,
#   'nav': 3709.0,
#   'threeMonthEarnRate': -5.8824,
#   'quant': 13726794,
#   'amonut': 50806,
#   'marketSum': 11635},
#  {'itemcode': '233740',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스닥150 레버리지',
#   'nowVal': 15525,
#   'risefall': '2',
#   'changeVal': 210,
#   'changeRate': 1.37,
#   'nav': 15729.0,
#   'threeMonthEarnRate': 4.0421,
#   'quant': 6973058,
#   'amonut': 107645,
#   'marketSum': 10184},
#  {'itemcode': '371460',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나전기차SOLACTIVE',
#   'nowVal': 14595,
#   'risefall': '2',
#   'changeVal': 50,
#   'changeRate': 0.34,
#   'nav': None,
#   'threeMonthEarnRate': 37.8019,
#   'quant': 1943473,
#   'amonut': 28329,
#   'marketSum': 10106},
#  {'itemcode': '292150',
#   'etfTabCode': 2,
#   'itemname': 'TIGER TOP10',
#   'nowVal': 15070,
#   'risefall': '5',
#   'changeVal': -85,
#   'changeRate': -0.56,
#   'nav': 15078.0,
#   'threeMonthEarnRate': 4.4452,
#   'quant': 302630,
#   'amonut': 4563,
#   'marketSum': 9848},
#  {'itemcode': '157450',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 단기통안채',
#   'nowVal': 100185,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 100186.0,
#   'threeMonthEarnRate': 0.0499,
#   'quant': 1068,
#   'amonut': 106,
#   'marketSum': 9512},
#  {'itemcode': '139260',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 IT',
#   'nowVal': 38805,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': -0.01,
#   'nav': 38822.0,
#   'threeMonthEarnRate': 0.9415,
#   'quant': 123937,
#   'amonut': 4806,
#   'marketSum': 9259},
#  {'itemcode': '305540',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 2차전지테마',
#   'nowVal': 18470,
#   'risefall': '5',
#   'changeVal': -45,
#   'changeRate': -0.24,
#   'nav': 18471.0,
#   'threeMonthEarnRate': 12.2461,
#   'quant': 736526,
#   'amonut': 13614,
#   'marketSum': 8736},
#  {'itemcode': '152100',
#   'etfTabCode': 1,
#   'itemname': 'ARIRANG 200',
#   'nowVal': 44040,
#   'risefall': '5',
#   'changeVal': -380,
#   'changeRate': -0.86,
#   'nav': 44146.0,
#   'threeMonthEarnRate': 5.7165,
#   'quant': 214674,
#   'amonut': 9454,
#   'marketSum': 8654},
#  {'itemcode': '364980',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX2차전지K-뉴딜',
#   'nowVal': 17050,
#   'risefall': '5',
#   'changeVal': -180,
#   'changeRate': -1.04,
#   'nav': 17041.0,
#   'threeMonthEarnRate': 12.3207,
#   'quant': 1591109,
#   'amonut': 27454,
#   'marketSum': 8005},
#  {'itemcode': '133690',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국나스닥100',
#   'nowVal': 73980,
#   'risefall': '2',
#   'changeVal': 330,
#   'changeRate': 0.45,
#   'nav': None,
#   'threeMonthEarnRate': 12.2302,
#   'quant': 61573,
#   'amonut': 4554,
#   'marketSum': 7768},
#  {'itemcode': '105190',
#   'etfTabCode': 1,
#   'itemname': 'KINDEX 200',
#   'nowVal': 43695,
#   'risefall': '5',
#   'changeVal': -400,
#   'changeRate': -0.91,
#   'nav': 43818.0,
#   'threeMonthEarnRate': 5.6091,
#   'quant': 414081,
#   'amonut': 18085,
#   'marketSum': 7472},
#  {'itemcode': '310970',
#   'etfTabCode': 1,
#   'itemname': 'TIGER MSCI Korea TR',
#   'nowVal': 17645,
#   'risefall': '5',
#   'changeVal': -120,
#   'changeRate': -0.68,
#   'nav': 17628.0,
#   'threeMonthEarnRate': 3.8281,
#   'quant': 2146,
#   'amonut': 37,
#   'marketSum': 7323},
#  {'itemcode': '293180',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 200',
#   'nowVal': 43610,
#   'risefall': '5',
#   'changeVal': -395,
#   'changeRate': -0.9,
#   'nav': 43739.0,
#   'threeMonthEarnRate': 5.525,
#   'quant': 112747,
#   'amonut': 4928,
#   'marketSum': 6302},
#  {'itemcode': '229200',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스닥 150',
#   'nowVal': 14680,
#   'risefall': '2',
#   'changeVal': 105,
#   'changeRate': 0.72,
#   'nav': 14823.0,
#   'threeMonthEarnRate': 2.1731,
#   'quant': 1623918,
#   'amonut': 23747,
#   'marketSum': 5967},
#  {'itemcode': '069660',
#   'etfTabCode': 1,
#   'itemname': 'KOSEF 200',
#   'nowVal': 43625,
#   'risefall': '5',
#   'changeVal': -405,
#   'changeRate': -0.92,
#   'nav': 43733.0,
#   'threeMonthEarnRate': 5.6863,
#   'quant': 2109,
#   'amonut': 92,
#   'marketSum': 5868},
#  {'itemcode': '314250',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국FANG플러스(H)',
#   'nowVal': 28905,
#   'risefall': '5',
#   'changeVal': -60,
#   'changeRate': -0.21,
#   'nav': None,
#   'threeMonthEarnRate': 14.7583,
#   'quant': 246931,
#   'amonut': 7135,
#   'marketSum': 5824},
#  {'itemcode': '091180',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 자동차',
#   'nowVal': 24845,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.14,
#   'nav': 24833.0,
#   'threeMonthEarnRate': 7.2493,
#   'quant': 587265,
#   'amonut': 14459,
#   'marketSum': 5429},
#  {'itemcode': '315930',
#   'etfTabCode': 2,
#   'itemname': 'KODEX Top5PlusTR',
#   'nowVal': 20065,
#   'risefall': '5',
#   'changeVal': -230,
#   'changeRate': -1.13,
#   'nav': 20041.0,
#   'threeMonthEarnRate': 2.6036,
#   'quant': 4227,
#   'amonut': 84,
#   'marketSum': 5217},
#  {'itemcode': '294400',
#   'etfTabCode': 1,
#   'itemname': 'KOSEF 200TR',
#   'nowVal': 51845,
#   'risefall': '5',
#   'changeVal': -475,
#   'changeRate': -0.91,
#   'nav': 51974.0,
#   'threeMonthEarnRate': 5.7183,
#   'quant': 4397,
#   'amonut': 228,
#   'marketSum': 5029},
#  {'itemcode': '364960',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX BBIG K-뉴딜',
#   'nowVal': 13365,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.49,
#   'nav': 13362.0,
#   'threeMonthEarnRate': 10.8333,
#   'quant': 780149,
#   'amonut': 10433,
#   'marketSum': 4999},
#  {'itemcode': '295040',
#   'etfTabCode': 1,
#   'itemname': 'SMART 200TR',
#   'nowVal': 14850,
#   'risefall': '5',
#   'changeVal': -70,
#   'changeRate': -0.47,
#   'nav': 14884.0,
#   'threeMonthEarnRate': 5.2928,
#   'quant': 4027,
#   'amonut': 59,
#   'marketSum': 4544},
#  {'itemcode': '251340',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 코스닥150선물인버스',
#   'nowVal': 4360,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.57,
#   'nav': 4355.0,
#   'threeMonthEarnRate': -4.1531,
#   'quant': 25416475,
#   'amonut': 111211,
#   'marketSum': 4238},
#  {'itemcode': '360750',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국S&P500',
#   'nowVal': 12310,
#   'risefall': '2',
#   'changeVal': 100,
#   'changeRate': 0.82,
#   'nav': None,
#   'threeMonthEarnRate': 7.615,
#   'quant': 299098,
#   'amonut': 3677,
#   'marketSum': 3595},
#  {'itemcode': '385540',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KIS종합채권(A-이상)액티브',
#   'nowVal': 100000,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.02,
#   'nav': 100048.0,
#   'threeMonthEarnRate': None,
#   'quant': 42,
#   'amonut': 4,
#   'marketSum': 3491},
#  {'itemcode': '226490',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스피',
#   'nowVal': 32920,
#   'risefall': '5',
#   'changeVal': -235,
#   'changeRate': -0.71,
#   'nav': 33019.0,
#   'threeMonthEarnRate': 7.6495,
#   'quant': 46831,
#   'amonut': 1546,
#   'marketSum': 3490},
#  {'itemcode': '332500',
#   'etfTabCode': 1,
#   'itemname': 'KINDEX 200TR',
#   'nowVal': 26600,
#   'risefall': '5',
#   'changeVal': -225,
#   'changeRate': -0.84,
#   'nav': 26658.0,
#   'threeMonthEarnRate': 5.4441,
#   'quant': 646,
#   'amonut': 17,
#   'marketSum': 3405},
#  {'itemcode': '381180',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국필라델피아반도체나스닥',
#   'nowVal': 10215,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.34,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 791425,
#   'amonut': 8080,
#   'marketSum': 3340},
#  {'itemcode': '290130',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR ESG사회책임투자',
#   'nowVal': 14230,
#   'risefall': '5',
#   'changeVal': -115,
#   'changeRate': -0.8,
#   'nav': 14260.0,
#   'threeMonthEarnRate': 4.9992,
#   'quant': 129687,
#   'amonut': 1845,
#   'marketSum': 3244},
#  {'itemcode': '357870',
#   'etfTabCode': 7,
#   'itemname': 'TIGER CD금리투자KIS(합성)',
#   'nowVal': 50340,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.01,
#   'nav': 50342.0,
#   'threeMonthEarnRate': 0.1791,
#   'quant': 50,
#   'amonut': 2,
#   'marketSum': 3154},
#  {'itemcode': '192090',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나CSI300',
#   'nowVal': 12090,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.33,
#   'nav': None,
#   'threeMonthEarnRate': 4.2838,
#   'quant': 337942,
#   'amonut': 4087,
#   'marketSum': 3071},
#  {'itemcode': '282000',
#   'etfTabCode': 3,
#   'itemname': 'KBSTAR 국고채3년선물인버스',
#   'nowVal': 100085,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 100132.0,
#   'threeMonthEarnRate': 0.3609,
#   'quant': 42,
#   'amonut': 4,
#   'marketSum': 3036},
#  {'itemcode': '251350',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 선진국MSCI World',
#   'nowVal': 19200,
#   'risefall': '2',
#   'changeVal': 90,
#   'changeRate': 0.47,
#   'nav': None,
#   'threeMonthEarnRate': 6.5514,
#   'quant': 126890,
#   'amonut': 2429,
#   'marketSum': 2880},
#  {'itemcode': '332940',
#   'etfTabCode': 1,
#   'itemname': 'HANARO MSCI Korea TR',
#   'nowVal': 17550,
#   'risefall': '5',
#   'changeVal': -180,
#   'changeRate': -1.02,
#   'nav': 17604.0,
#   'threeMonthEarnRate': 3.9577,
#   'quant': 50,
#   'amonut': 0,
#   'marketSum': 2843},
#  {'itemcode': '091170',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 은행',
#   'nowVal': 7585,
#   'risefall': '5',
#   'changeVal': -80,
#   'changeRate': -1.04,
#   'nav': 7574.0,
#   'threeMonthEarnRate': 10.4148,
#   'quant': 1272872,
#   'amonut': 9657,
#   'marketSum': 2799},
#  {'itemcode': '275980',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#   'nowVal': 18755,
#   'risefall': '5',
#   'changeVal': -60,
#   'changeRate': -0.32,
#   'nav': None,
#   'threeMonthEarnRate': 7.9151,
#   'quant': 91035,
#   'amonut': 1705,
#   'marketSum': 2738},
#  {'itemcode': '367770',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR Fn수소경제테마',
#   'nowVal': 12870,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.19,
#   'nav': 12888.0,
#   'threeMonthEarnRate': 1.2961,
#   'quant': 148488,
#   'amonut': 1906,
#   'marketSum': 2735},
#  {'itemcode': '091160',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 반도체',
#   'nowVal': 38220,
#   'risefall': '5',
#   'changeVal': -305,
#   'changeRate': -0.79,
#   'nav': 38301.0,
#   'threeMonthEarnRate': 5.8815,
#   'quant': 148074,
#   'amonut': 5678,
#   'marketSum': 2695},
#  {'itemcode': '168580',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 중국본토CSI300',
#   'nowVal': 32405,
#   'risefall': '2',
#   'changeVal': 175,
#   'changeRate': 0.54,
#   'nav': None,
#   'threeMonthEarnRate': 4.4732,
#   'quant': 13788,
#   'amonut': 447,
#   'marketSum': 2592},
#  {'itemcode': '261220',
#   'etfTabCode': 5,
#   'itemname': 'KODEX WTI원유선물(H)',
#   'nowVal': 11080,
#   'risefall': '2',
#   'changeVal': 50,
#   'changeRate': 0.45,
#   'nav': None,
#   'threeMonthEarnRate': 19.3722,
#   'quant': 381617,
#   'amonut': 4222,
#   'marketSum': 2535},
#  {'itemcode': '190620',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX 단기통안채',
#   'nowVal': 100315,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 100311.0,
#   'threeMonthEarnRate': 0.0748,
#   'quant': 741,
#   'amonut': 74,
#   'marketSum': 2522},
#  {'itemcode': '385550',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KIS단기종합채권(AA-이상)액티브',
#   'nowVal': 99865,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.01,
#   'nav': 99873.0,
#   'threeMonthEarnRate': None,
#   'quant': 42,
#   'amonut': 4,
#   'marketSum': 2502},
#  {'itemcode': '272580',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 단기채권액티브',
#   'nowVal': 50060,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 50062.0,
#   'threeMonthEarnRate': -0.04,
#   'quant': 4583,
#   'amonut': 229,
#   'marketSum': 2417},
#  {'itemcode': '360200',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 미국S&P500',
#   'nowVal': 12395,
#   'risefall': '2',
#   'changeVal': 105,
#   'changeRate': 0.85,
#   'nav': None,
#   'threeMonthEarnRate': 7.7503,
#   'quant': 143612,
#   'amonut': 1777,
#   'marketSum': 2405},
#  {'itemcode': '132030',
#   'etfTabCode': 5,
#   'itemname': 'KODEX 골드선물(H)',
#   'nowVal': 12070,
#   'risefall': '2',
#   'changeVal': 130,
#   'changeRate': 1.09,
#   'nav': None,
#   'threeMonthEarnRate': 2.7096,
#   'quant': 299713,
#   'amonut': 3605,
#   'marketSum': 2402},
#  {'itemcode': '143850',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국S&P500선물(H)',
#   'nowVal': 50175,
#   'risefall': '2',
#   'changeVal': 130,
#   'changeRate': 0.26,
#   'nav': None,
#   'threeMonthEarnRate': 8.2639,
#   'quant': 44268,
#   'amonut': 2220,
#   'marketSum': 2358},
#  {'itemcode': '371160',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나항셍테크',
#   'nowVal': 10390,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 0.92,
#   'nav': None,
#   'threeMonthEarnRate': -0.6275,
#   'quant': 209820,
#   'amonut': 2166,
#   'marketSum': 2317},
#  {'itemcode': '196230',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 단기통안채',
#   'nowVal': 104430,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.01,
#   'nav': 104432.0,
#   'threeMonthEarnRate': 0.0622,
#   'quant': 578275,
#   'amonut': 60388,
#   'marketSum': 2289},
#  {'itemcode': '272560',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 단기국공채액티브',
#   'nowVal': 101990,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': 0.0,
#   'nav': 101992.0,
#   'threeMonthEarnRate': 0.0981,
#   'quant': 801486,
#   'amonut': 81747,
#   'marketSum': 2270},
#  {'itemcode': '332930',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 200TR',
#   'nowVal': 51890,
#   'risefall': '5',
#   'changeVal': -450,
#   'changeRate': -0.86,
#   'nav': 52001.0,
#   'threeMonthEarnRate': 5.6093,
#   'quant': 2081,
#   'amonut': 107,
#   'marketSum': 2257},
#  {'itemcode': '232080',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 코스닥150',
#   'nowVal': 14890,
#   'risefall': '2',
#   'changeVal': 115,
#   'changeRate': 0.78,
#   'nav': 15031.0,
#   'threeMonthEarnRate': 2.2137,
#   'quant': 455267,
#   'amonut': 6762,
#   'marketSum': 2183},
#  {'itemcode': '245710',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 베트남VN30(합성)',
#   'nowVal': 22405,
#   'risefall': '2',
#   'changeVal': 280,
#   'changeRate': 1.27,
#   'nav': None,
#   'threeMonthEarnRate': 29.5374,
#   'quant': 94924,
#   'amonut': 2117,
#   'marketSum': 2106},
#  {'itemcode': '381170',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국테크TOP10 INDXX',
#   'nowVal': 10750,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.33,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 590150,
#   'amonut': 6334,
#   'marketSum': 2053},
#  {'itemcode': '161510',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG 고배당주',
#   'nowVal': 12560,
#   'risefall': '5',
#   'changeVal': -120,
#   'changeRate': -0.95,
#   'nav': 12563.0,
#   'threeMonthEarnRate': 11.355,
#   'quant': 134936,
#   'amonut': 1698,
#   'marketSum': 1922},
#  {'itemcode': '302450',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 코스피',
#   'nowVal': 33030,
#   'risefall': '5',
#   'changeVal': -120,
#   'changeRate': -0.36,
#   'nav': 33004.0,
#   'threeMonthEarnRate': 6.9941,
#   'quant': 107,
#   'amonut': 3,
#   'marketSum': 1916},
#  {'itemcode': '278240',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 코스닥150선물레버리지',
#   'nowVal': 15800,
#   'risefall': '2',
#   'changeVal': 200,
#   'changeRate': 1.28,
#   'nav': 15880.0,
#   'threeMonthEarnRate': 4.7683,
#   'quant': 73152,
#   'amonut': 1151,
#   'marketSum': 1901},
#  {'itemcode': '267770',
#   'etfTabCode': 3,
#   'itemname': 'TIGER 200선물레버리지',
#   'nowVal': 21815,
#   'risefall': '5',
#   'changeVal': -320,
#   'changeRate': -1.45,
#   'nav': 21850.0,
#   'threeMonthEarnRate': 11.008,
#   'quant': 830189,
#   'amonut': 18130,
#   'marketSum': 1832},
#  {'itemcode': '270810',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 코스닥150',
#   'nowVal': 14535,
#   'risefall': '2',
#   'changeVal': 85,
#   'changeRate': 0.59,
#   'nav': 14696.0,
#   'threeMonthEarnRate': 2.1201,
#   'quant': 10864,
#   'amonut': 157,
#   'marketSum': 1704},
#  {'itemcode': '150460',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 중국소비테마',
#   'nowVal': 9330,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.21,
#   'nav': 9346.0,
#   'threeMonthEarnRate': 14.1496,
#   'quant': 54797,
#   'amonut': 510,
#   'marketSum': 1702},
#  {'itemcode': '367380',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 미국나스닥100',
#   'nowVal': 12700,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 0.47,
#   'nav': None,
#   'threeMonthEarnRate': 12.2458,
#   'quant': 86621,
#   'amonut': 1099,
#   'marketSum': 1651},
#  {'itemcode': '143860',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 헬스케어',
#   'nowVal': 45515,
#   'risefall': '2',
#   'changeVal': 780,
#   'changeRate': 1.74,
#   'nav': 45703.0,
#   'threeMonthEarnRate': -1.584,
#   'quant': 58676,
#   'amonut': 2655,
#   'marketSum': 1557},
#  {'itemcode': '326240',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR IT플러스',
#   'nowVal': 22760,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.04,
#   'nav': 22773.0,
#   'threeMonthEarnRate': 7.6697,
#   'quant': 296444,
#   'amonut': 6753,
#   'marketSum': 1552},
#  {'itemcode': '091230',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 반도체',
#   'nowVal': 39220,
#   'risefall': '5',
#   'changeVal': -175,
#   'changeRate': -0.44,
#   'nav': 39218.0,
#   'threeMonthEarnRate': 5.6392,
#   'quant': 59629,
#   'amonut': 2339,
#   'marketSum': 1490},
#  {'itemcode': '108450',
#   'etfTabCode': 2,
#   'itemname': 'KINDEX 삼성그룹섹터가중',
#   'nowVal': 17090,
#   'risefall': '2',
#   'changeVal': 90,
#   'changeRate': 0.53,
#   'nav': 17136.0,
#   'threeMonthEarnRate': 6.8107,
#   'quant': 2110,
#   'amonut': 36,
#   'marketSum': 1470},
#  {'itemcode': '148070',
#   'etfTabCode': 6,
#   'itemname': 'KOSEF 국고채10년',
#   'nowVal': 120435,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.03,
#   'nav': 120403.0,
#   'threeMonthEarnRate': 0.1872,
#   'quant': 4263,
#   'amonut': 513,
#   'marketSum': 1469},
#  {'itemcode': '298770',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 한국대만IT프리미어',
#   'nowVal': 20325,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.07,
#   'nav': None,
#   'threeMonthEarnRate': 1.2967,
#   'quant': 21221,
#   'amonut': 430,
#   'marketSum': 1443},
#  {'itemcode': '138540',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 현대차그룹+펀더멘털',
#   'nowVal': 28530,
#   'risefall': '5',
#   'changeVal': -45,
#   'changeRate': -0.16,
#   'nav': 28546.0,
#   'threeMonthEarnRate': 8.8944,
#   'quant': 72968,
#   'amonut': 2071,
#   'marketSum': 1369},
#  {'itemcode': '182480',
#   'etfTabCode': 7,
#   'itemname': 'TIGER 미국MSCI리츠(합성 H)',
#   'nowVal': 14655,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.24,
#   'nav': None,
#   'threeMonthEarnRate': 10.9851,
#   'quant': 67557,
#   'amonut': 989,
#   'marketSum': 1363},
#  {'itemcode': '204480',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나CSI300레버리지(합성)',
#   'nowVal': 33480,
#   'risefall': '2',
#   'changeVal': 410,
#   'changeRate': 1.24,
#   'nav': None,
#   'threeMonthEarnRate': 6.1296,
#   'quant': 95895,
#   'amonut': 3199,
#   'marketSum': 1272},
#  {'itemcode': '283580',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 중국본토CSI300',
#   'nowVal': 14685,
#   'risefall': '2',
#   'changeVal': 110,
#   'changeRate': 0.75,
#   'nav': None,
#   'threeMonthEarnRate': 4.3307,
#   'quant': 145843,
#   'amonut': 2137,
#   'marketSum': 1263},
#  {'itemcode': '219480',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국S&P500선물(H)',
#   'nowVal': 20650,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.27,
#   'nav': None,
#   'threeMonthEarnRate': 8.3377,
#   'quant': 264755,
#   'amonut': 5468,
#   'marketSum': 1260},
#  {'itemcode': '328370',
#   'etfTabCode': 1,
#   'itemname': 'ARIRANG 코스피TR',
#   'nowVal': 16475,
#   'risefall': '5',
#   'changeVal': -85,
#   'changeRate': -0.51,
#   'nav': 16475.0,
#   'threeMonthEarnRate': 7.2191,
#   'quant': 37,
#   'amonut': 0,
#   'marketSum': 1244},
#  {'itemcode': '372330',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 차이나항셍테크',
#   'nowVal': 10410,
#   'risefall': '2',
#   'changeVal': 80,
#   'changeRate': 0.77,
#   'nav': None,
#   'threeMonthEarnRate': -0.7209,
#   'quant': 114314,
#   'amonut': 1184,
#   'marketSum': 1228},
#  {'itemcode': '367760',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR Fn5G테크',
#   'nowVal': 11555,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.22,
#   'nav': 11555.0,
#   'threeMonthEarnRate': 1.5878,
#   'quant': 130031,
#   'amonut': 1502,
#   'marketSum': 1219},
#  {'itemcode': '252710',
#   'etfTabCode': 3,
#   'itemname': 'TIGER 200선물인버스2X',
#   'nowVal': 1945,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 1.57,
#   'nav': 1946.0,
#   'threeMonthEarnRate': -11.5474,
#   'quant': 2284776,
#   'amonut': 4436,
#   'marketSum': 1216},
#  {'itemcode': '136340',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 중기우량회사채',
#   'nowVal': 104975,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.03,
#   'nav': 104937.0,
#   'threeMonthEarnRate': -0.1617,
#   'quant': 671,
#   'amonut': 70,
#   'marketSum': 1197},
#  {'itemcode': '273140',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 단기변동금리부채권액티브',
#   'nowVal': 102555,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 102561.0,
#   'threeMonthEarnRate': 0.0683,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 1139},
#  {'itemcode': '233160',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 코스닥150 레버리지',
#   'nowVal': 16490,
#   'risefall': '2',
#   'changeVal': 205,
#   'changeRate': 1.26,
#   'nav': 16713.0,
#   'threeMonthEarnRate': 3.8915,
#   'quant': 863894,
#   'amonut': 14200,
#   'marketSum': 1113},
#  {'itemcode': '139280',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 경기방어',
#   'nowVal': 12780,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.04,
#   'nav': 12776.0,
#   'threeMonthEarnRate': 2.249,
#   'quant': 19404,
#   'amonut': 246,
#   'marketSum': 1109},
#  {'itemcode': '329200',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 부동산인프라고배당',
#   'nowVal': 5925,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.34,
#   'nav': 5947.0,
#   'threeMonthEarnRate': 13.4325,
#   'quant': 158382,
#   'amonut': 939,
#   'marketSum': 1081},
#  {'itemcode': '390950',
#   'etfTabCode': 6,
#   'itemname': 'HANARO 단기채권액티브',
#   'nowVal': 100040,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 100038.0,
#   'threeMonthEarnRate': None,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 1069},
#  {'itemcode': '325010',
#   'etfTabCode': 2,
#   'itemname': 'KODEX Fn성장',
#   'nowVal': 19025,
#   'risefall': '5',
#   'changeVal': -45,
#   'changeRate': -0.24,
#   'nav': 18999.0,
#   'threeMonthEarnRate': 4.9128,
#   'quant': 1189,
#   'amonut': 22,
#   'marketSum': 1065},
#  {'itemcode': '225040',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국S&P500레버리지(합성 H)',
#   'nowVal': 31640,
#   'risefall': '2',
#   'changeVal': 120,
#   'changeRate': 0.38,
#   'nav': None,
#   'threeMonthEarnRate': 16.1171,
#   'quant': 4797,
#   'amonut': 151,
#   'marketSum': 1044},
#  {'itemcode': '176950',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 국채선물10년인버스',
#   'nowVal': 47180,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.06,
#   'nav': 47215.0,
#   'threeMonthEarnRate': -0.2747,
#   'quant': 46,
#   'amonut': 2,
#   'marketSum': 1042},
#  {'itemcode': '144600',
#   'etfTabCode': 5,
#   'itemname': 'KODEX 은선물(H)',
#   'nowVal': 5425,
#   'risefall': '2',
#   'changeVal': 85,
#   'changeRate': 1.59,
#   'nav': None,
#   'threeMonthEarnRate': 4.3988,
#   'quant': 320589,
#   'amonut': 1734,
#   'marketSum': 1042},
#  {'itemcode': '156080',
#   'etfTabCode': 1,
#   'itemname': 'KODEX MSCI Korea',
#   'nowVal': 20415,
#   'risefall': '5',
#   'changeVal': -125,
#   'changeRate': -0.61,
#   'nav': 20436.0,
#   'threeMonthEarnRate': 3.7321,
#   'quant': 224,
#   'amonut': 4,
#   'marketSum': 1021},
#  {'itemcode': '325020',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 배당가치',
#   'nowVal': 13825,
#   'risefall': '5',
#   'changeVal': -140,
#   'changeRate': -1.0,
#   'nav': 13807.0,
#   'threeMonthEarnRate': 7.7629,
#   'quant': 6470,
#   'amonut': 89,
#   'marketSum': 995},
#  {'itemcode': '376410',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 탄소효율그린뉴딜',
#   'nowVal': 10495,
#   'risefall': '5',
#   'changeVal': -45,
#   'changeRate': -0.43,
#   'nav': 10504.0,
#   'threeMonthEarnRate': 5.6112,
#   'quant': 12669,
#   'amonut': 132,
#   'marketSum': 976},
#  {'itemcode': '228800',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 여행레저',
#   'nowVal': 5330,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -0.74,
#   'nav': 5309.0,
#   'threeMonthEarnRate': 13.1717,
#   'quant': 402987,
#   'amonut': 2154,
#   'marketSum': 956},
#  {'itemcode': '117700',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 건설',
#   'nowVal': 3890,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.64,
#   'nav': 3902.0,
#   'threeMonthEarnRate': 17.1103,
#   'quant': 571371,
#   'amonut': 2226,
#   'marketSum': 945},
#  {'itemcode': '114260',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 국고채3년',
#   'nowVal': 57845,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.11,
#   'nav': 57827.0,
#   'threeMonthEarnRate': -0.302,
#   'quant': 37695,
#   'amonut': 2181,
#   'marketSum': 937},
#  {'itemcode': '371470',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나바이오테크SOLACTIVE',
#   'nowVal': 13455,
#   'risefall': '2',
#   'changeVal': 120,
#   'changeRate': 0.9,
#   'nav': None,
#   'threeMonthEarnRate': 15.8557,
#   'quant': 65862,
#   'amonut': 883,
#   'marketSum': 931},
#  {'itemcode': '368190',
#   'etfTabCode': 2,
#   'itemname': 'HANARO Fn K-뉴딜디지털플러스',
#   'nowVal': 13610,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.11,
#   'nav': 13616.0,
#   'threeMonthEarnRate': 9.3938,
#   'quant': 98691,
#   'amonut': 1347,
#   'marketSum': 925},
#  {'itemcode': '364970',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX바이오K-뉴딜',
#   'nowVal': 10725,
#   'risefall': '2',
#   'changeVal': 215,
#   'changeRate': 2.05,
#   'nav': 10723.0,
#   'threeMonthEarnRate': 1.0091,
#   'quant': 375965,
#   'amonut': 3979,
#   'marketSum': 879},
#  {'itemcode': '368590',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국나스닥100',
#   'nowVal': 12300,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 0.49,
#   'nav': None,
#   'threeMonthEarnRate': 12.242,
#   'quant': 78213,
#   'amonut': 961,
#   'marketSum': 873},
#  {'itemcode': '195930',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 유로스탁스50(합성 H)',
#   'nowVal': 13865,
#   'risefall': '5',
#   'changeVal': -85,
#   'changeRate': -0.61,
#   'nav': None,
#   'threeMonthEarnRate': 5.9627,
#   'quant': 94994,
#   'amonut': 1313,
#   'marketSum': 818},
#  {'itemcode': '130680',
#   'etfTabCode': 5,
#   'itemname': 'TIGER 원유선물Enhanced(H)',
#   'nowVal': 3335,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.15,
#   'nav': None,
#   'threeMonthEarnRate': 19.5691,
#   'quant': 277703,
#   'amonut': 925,
#   'marketSum': 785},
#  {'itemcode': '174360',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 중국본토대형주CSI100',
#   'nowVal': 22270,
#   'risefall': '2',
#   'changeVal': 240,
#   'changeRate': 1.09,
#   'nav': None,
#   'threeMonthEarnRate': 0.7546,
#   'quant': 20914,
#   'amonut': 464,
#   'marketSum': 779},
#  {'itemcode': '309230',
#   'etfTabCode': 2,
#   'itemname': 'KINDEX 미국WideMoat가치주',
#   'nowVal': 16885,
#   'risefall': '2',
#   'changeVal': 105,
#   'changeRate': 0.63,
#   'nav': None,
#   'threeMonthEarnRate': 5.5677,
#   'quant': 46142,
#   'amonut': 778,
#   'marketSum': 777},
#  {'itemcode': '256750',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 심천ChiNext(합성)',
#   'nowVal': 14795,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.44,
#   'nav': None,
#   'threeMonthEarnRate': 22.8011,
#   'quant': 117892,
#   'amonut': 1738,
#   'marketSum': 769},
#  {'itemcode': '195980',
#   'etfTabCode': 4,
#   'itemname': 'ARIRANG 신흥국MSCI(합성 H)',
#   'nowVal': 13160,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.08,
#   'nav': None,
#   'threeMonthEarnRate': 3.6657,
#   'quant': 33681,
#   'amonut': 442,
#   'marketSum': 745},
#  {'itemcode': '266160',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 고배당',
#   'nowVal': 12875,
#   'risefall': '5',
#   'changeVal': -150,
#   'changeRate': -1.15,
#   'nav': 12880.0,
#   'threeMonthEarnRate': 8.0823,
#   'quant': 69163,
#   'amonut': 892,
#   'marketSum': 740},
#  {'itemcode': '261240',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 미국달러선물',
#   'nowVal': 10040,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.55,
#   'nav': 10045.0,
#   'threeMonthEarnRate': -0.6962,
#   'quant': 89244,
#   'amonut': 894,
#   'marketSum': 735},
#  {'itemcode': '304940',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국나스닥100선물(H)',
#   'nowVal': 18475,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.11,
#   'nav': None,
#   'threeMonthEarnRate': 12.7743,
#   'quant': 261749,
#   'amonut': 4836,
#   'marketSum': 730},
#  {'itemcode': '123310',
#   'etfTabCode': 3,
#   'itemname': 'TIGER 인버스',
#   'nowVal': 4095,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.49,
#   'nav': 4101.0,
#   'threeMonthEarnRate': -5.6713,
#   'quant': 105473,
#   'amonut': 431,
#   'marketSum': 729},
#  {'itemcode': '385520',
#   'etfTabCode': 2,
#   'itemname': 'KODEX K-미래차액티브',
#   'nowVal': 11080,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.31,
#   'nav': 11096.0,
#   'threeMonthEarnRate': None,
#   'quant': 350310,
#   'amonut': 3863,
#   'marketSum': 726},
#  {'itemcode': '139220',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 건설',
#   'nowVal': 3380,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 3377.0,
#   'threeMonthEarnRate': 17.036,
#   'quant': 1007061,
#   'amonut': 3406,
#   'marketSum': 694},
#  {'itemcode': '157490',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 소프트웨어',
#   'nowVal': 19565,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.18,
#   'nav': 19569.0,
#   'threeMonthEarnRate': 18.2561,
#   'quant': 155273,
#   'amonut': 3049,
#   'marketSum': 689},
#  {'itemcode': '277630',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 코스피',
#   'nowVal': 33315,
#   'risefall': '5',
#   'changeVal': -60,
#   'changeRate': -0.18,
#   'nav': 33317.0,
#   'threeMonthEarnRate': 7.3772,
#   'quant': 485,
#   'amonut': 16,
#   'marketSum': 666},
#  {'itemcode': '245360',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나HSCEI',
#   'nowVal': 12745,
#   'risefall': '5',
#   'changeVal': -85,
#   'changeRate': -0.66,
#   'nav': None,
#   'threeMonthEarnRate': -1.9488,
#   'quant': 7827,
#   'amonut': 100,
#   'marketSum': 663},
#  {'itemcode': '114820',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 국채3년',
#   'nowVal': 110265,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 110248.0,
#   'threeMonthEarnRate': -0.2037,
#   'quant': 469,
#   'amonut': 51,
#   'marketSum': 662},
#  {'itemcode': '289260',
#   'etfTabCode': 2,
#   'itemname': 'TIGER MSCI KOREA ESG리더스',
#   'nowVal': 12350,
#   'risefall': '5',
#   'changeVal': -95,
#   'changeRate': -0.76,
#   'nav': 12398.0,
#   'threeMonthEarnRate': 5.4303,
#   'quant': 1646,
#   'amonut': 20,
#   'marketSum': 652},
#  {'itemcode': '385560',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KIS국고채30년Enhanced',
#   'nowVal': 102485,
#   'risefall': '2',
#   'changeVal': 685,
#   'changeRate': 0.67,
#   'nav': 102694.0,
#   'threeMonthEarnRate': None,
#   'quant': 43,
#   'amonut': 4,
#   'marketSum': 646},
#  {'itemcode': '363510',
#   'etfTabCode': 6,
#   'itemname': 'SMART KIS단기통안채',
#   'nowVal': 100320,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 100323.0,
#   'threeMonthEarnRate': 0.0648,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 636},
#  {'itemcode': '306520',
#   'etfTabCode': 3,
#   'itemname': 'HANARO 200선물인버스',
#   'nowVal': 8535,
#   'risefall': '2',
#   'changeVal': 50,
#   'changeRate': 0.59,
#   'nav': 8530.0,
#   'threeMonthEarnRate': -5.407,
#   'quant': 719,
#   'amonut': 6,
#   'marketSum': 632},
#  {'itemcode': '379800',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국S&P500TR',
#   'nowVal': 10725,
#   'risefall': '2',
#   'changeVal': 90,
#   'changeRate': 0.85,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 110550,
#   'amonut': 1184,
#   'marketSum': 622},
#  {'itemcode': '117680',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 철강',
#   'nowVal': 10170,
#   'risefall': '5',
#   'changeVal': -90,
#   'changeRate': -0.88,
#   'nav': 10190.0,
#   'threeMonthEarnRate': 18.5715,
#   'quant': 211063,
#   'amonut': 2147,
#   'marketSum': 619},
#  {'itemcode': '245340',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국다우존스30',
#   'nowVal': 19795,
#   'risefall': '2',
#   'changeVal': 240,
#   'changeRate': 1.23,
#   'nav': None,
#   'threeMonthEarnRate': 3.0566,
#   'quant': 25284,
#   'amonut': 499,
#   'marketSum': 614},
#  {'itemcode': '336160',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 금융채액티브',
#   'nowVal': 102800,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -0.05,
#   'nav': 102795.0,
#   'threeMonthEarnRate': -0.3102,
#   'quant': 46,
#   'amonut': 4,
#   'marketSum': 596},
#  {'itemcode': '315960',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 대형고배당10TR',
#   'nowVal': 17335,
#   'risefall': '5',
#   'changeVal': -210,
#   'changeRate': -1.2,
#   'nav': 17314.0,
#   'threeMonthEarnRate': 2.4226,
#   'quant': 6127,
#   'amonut': 106,
#   'marketSum': 589},
#  {'itemcode': '102970',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 증권',
#   'nowVal': 8450,
#   'risefall': '5',
#   'changeVal': -135,
#   'changeRate': -1.57,
#   'nav': 8450.0,
#   'threeMonthEarnRate': 11.8566,
#   'quant': 295829,
#   'amonut': 2509,
#   'marketSum': 583},
#  {'itemcode': '361580',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 200TR',
#   'nowVal': 22340,
#   'risefall': '5',
#   'changeVal': -160,
#   'changeRate': -0.71,
#   'nav': 22381.0,
#   'threeMonthEarnRate': 5.5347,
#   'quant': 967,
#   'amonut': 21,
#   'marketSum': 581},
#  {'itemcode': '139230',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 중공업',
#   'nowVal': 3850,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.39,
#   'nav': 3864.0,
#   'threeMonthEarnRate': 19.2901,
#   'quant': 299151,
#   'amonut': 1151,
#   'marketSum': 576},
#  {'itemcode': '387280',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 퓨처모빌리티액티브',
#   'nowVal': 10710,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.28,
#   'nav': 10742.0,
#   'threeMonthEarnRate': None,
#   'quant': 815772,
#   'amonut': 8746,
#   'marketSum': 571},
#  {'itemcode': '304780',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 200선물레버리지',
#   'nowVal': 31710,
#   'risefall': '5',
#   'changeVal': -440,
#   'changeRate': -1.37,
#   'nav': 31724.0,
#   'threeMonthEarnRate': 10.6903,
#   'quant': 2838,
#   'amonut': 90,
#   'marketSum': 571},
#  {'itemcode': '329750',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 미국달러단기채권액티브',
#   'nowVal': 9710,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.36,
#   'nav': None,
#   'threeMonthEarnRate': -0.463,
#   'quant': 118708,
#   'amonut': 1151,
#   'marketSum': 552},
#  {'itemcode': '219390',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국S&P원유생산기업(합성 H)',
#   'nowVal': 4395,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 2.21,
#   'nav': None,
#   'threeMonthEarnRate': 18.7845,
#   'quant': 299164,
#   'amonut': 1310,
#   'marketSum': 549},
#  {'itemcode': '337140',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 코스피대형주',
#   'nowVal': 15435,
#   'risefall': '5',
#   'changeVal': -70,
#   'changeRate': -0.45,
#   'nav': 15430.0,
#   'threeMonthEarnRate': 5.8578,
#   'quant': 13127,
#   'amonut': 202,
#   'marketSum': 540},
#  {'itemcode': '363580',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 200IT TR',
#   'nowVal': 14590,
#   'risefall': '5',
#   'changeVal': -50,
#   'changeRate': -0.34,
#   'nav': 14644.0,
#   'threeMonthEarnRate': 1.1398,
#   'quant': 3747,
#   'amonut': 54,
#   'marketSum': 540},
#  {'itemcode': '305080',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 미국채10년선물',
#   'nowVal': 11610,
#   'risefall': '2',
#   'changeVal': 90,
#   'changeRate': 0.78,
#   'nav': None,
#   'threeMonthEarnRate': 0.9198,
#   'quant': 30830,
#   'amonut': 357,
#   'marketSum': 534},
#  {'itemcode': '130730',
#   'etfTabCode': 6,
#   'itemname': 'KOSEF 단기자금',
#   'nowVal': 101060,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.01,
#   'nav': 101052.0,
#   'threeMonthEarnRate': 0.0594,
#   'quant': 874224,
#   'amonut': 88344,
#   'marketSum': 532},
#  {'itemcode': '266370',
#   'etfTabCode': 2,
#   'itemname': 'KODEX IT',
#   'nowVal': 21175,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.12,
#   'nav': 21212.0,
#   'threeMonthEarnRate': 0.1373,
#   'quant': 40721,
#   'amonut': 863,
#   'marketSum': 529},
#  {'itemcode': '322400',
#   'etfTabCode': 2,
#   'itemname': 'HANARO e커머스',
#   'nowVal': 20730,
#   'risefall': '5',
#   'changeVal': -85,
#   'changeRate': -0.41,
#   'nav': 20734.0,
#   'threeMonthEarnRate': 22.8385,
#   'quant': 182250,
#   'amonut': 3788,
#   'marketSum': 529},
#  {'itemcode': '375770',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 탄소효율그린뉴딜',
#   'nowVal': 10450,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -0.62,
#   'nav': 10485.0,
#   'threeMonthEarnRate': 5.5722,
#   'quant': 2873,
#   'amonut': 30,
#   'marketSum': 523},
#  {'itemcode': '371450',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌클라우드컴퓨팅INDXX',
#   'nowVal': 11400,
#   'risefall': '5',
#   'changeVal': -125,
#   'changeRate': -1.08,
#   'nav': None,
#   'threeMonthEarnRate': 14.0524,
#   'quant': 44259,
#   'amonut': 504,
#   'marketSum': 511},
#  {'itemcode': '243880',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200IT레버리지',
#   'nowVal': 68000,
#   'risefall': '5',
#   'changeVal': -250,
#   'changeRate': -0.37,
#   'nav': 68385.0,
#   'threeMonthEarnRate': 2.3852,
#   'quant': 3447,
#   'amonut': 234,
#   'marketSum': 510},
#  {'itemcode': '310960',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 200TR',
#   'nowVal': 23255,
#   'risefall': '5',
#   'changeVal': -155,
#   'changeRate': -0.66,
#   'nav': 23306.0,
#   'threeMonthEarnRate': 5.3555,
#   'quant': 1150,
#   'amonut': 26,
#   'marketSum': 488},
#  {'itemcode': '292190',
#   'etfTabCode': 1,
#   'itemname': 'KODEX KRX300',
#   'nowVal': 20065,
#   'risefall': '5',
#   'changeVal': -90,
#   'changeRate': -0.45,
#   'nav': 20068.0,
#   'threeMonthEarnRate': 4.9684,
#   'quant': 4440,
#   'amonut': 89,
#   'marketSum': 482},
#  {'itemcode': '228810',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 미디어컨텐츠',
#   'nowVal': 8375,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.36,
#   'nav': 8380.0,
#   'threeMonthEarnRate': 17.4524,
#   'quant': 223868,
#   'amonut': 1872,
#   'marketSum': 480},
#  {'itemcode': '302190',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 중장기국채',
#   'nowVal': 52160,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.06,
#   'nav': 52154.0,
#   'threeMonthEarnRate': -0.0576,
#   'quant': 7948,
#   'amonut': 414,
#   'marketSum': 480},
#  {'itemcode': '379810',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국나스닥100TR',
#   'nowVal': 10860,
#   'risefall': '2',
#   'changeVal': 45,
#   'changeRate': 0.42,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 219258,
#   'amonut': 2381,
#   'marketSum': 467},
#  {'itemcode': '329650',
#   'etfTabCode': 7,
#   'itemname': 'KODEX TRF3070',
#   'nowVal': 11220,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.18,
#   'nav': 11170.0,
#   'threeMonthEarnRate': 1.9108,
#   'quant': 57118,
#   'amonut': 640,
#   'marketSum': 460},
#  {'itemcode': '266360',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 미디어&엔터테인먼트',
#   'nowVal': 26225,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 0.36,
#   'nav': 26290.0,
#   'threeMonthEarnRate': 20.8044,
#   'quant': 43018,
#   'amonut': 1133,
#   'marketSum': 446},
#  {'itemcode': '365000',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX인터넷K-뉴딜',
#   'nowVal': 13035,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.11,
#   'nav': 13067.0,
#   'threeMonthEarnRate': 16.8307,
#   'quant': 169039,
#   'amonut': 2214,
#   'marketSum': 417},
#  {'itemcode': '114460',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX 국고채3년',
#   'nowVal': 106330,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.01,
#   'nav': 106307.0,
#   'threeMonthEarnRate': -0.244,
#   'quant': 544,
#   'amonut': 57,
#   'marketSum': 415},
#  {'itemcode': '272570',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 중장기국공채액티브',
#   'nowVal': 103300,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.02,
#   'nav': 103244.0,
#   'threeMonthEarnRate': -0.1258,
#   'quant': 24,
#   'amonut': 2,
#   'marketSum': 395},
#  {'itemcode': '341850',
#   'etfTabCode': 7,
#   'itemname': 'TIGER KIS부동산인프라채권TR',
#   'nowVal': 5780,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.43,
#   'nav': 5819.0,
#   'threeMonthEarnRate': 8.9322,
#   'quant': 354541,
#   'amonut': 2044,
#   'marketSum': 393},
#  {'itemcode': '256440',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 인도네시아MSCI(합성)',
#   'nowVal': 7785,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.39,
#   'nav': None,
#   'threeMonthEarnRate': -9.0323,
#   'quant': 29273,
#   'amonut': 228,
#   'marketSum': 381},
#  {'itemcode': '356540',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX KIS종합채권(AA-이상)액티브',
#   'nowVal': 98050,
#   'risefall': '2',
#   'changeVal': 50,
#   'changeRate': 0.05,
#   'nav': 98059.0,
#   'threeMonthEarnRate': -0.3559,
#   'quant': 2,
#   'amonut': 0,
#   'marketSum': 377},
#  {'itemcode': '280930',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국러셀2000(H)',
#   'nowVal': 15050,
#   'risefall': '2',
#   'changeVal': 85,
#   'changeRate': 0.57,
#   'nav': None,
#   'threeMonthEarnRate': 5.9094,
#   'quant': 254469,
#   'amonut': 3829,
#   'marketSum': 376},
#  {'itemcode': '304770',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 코스닥150',
#   'nowVal': 14675,
#   'risefall': '2',
#   'changeVal': 120,
#   'changeRate': 0.82,
#   'nav': 14812.0,
#   'threeMonthEarnRate': 2.5,
#   'quant': 8375,
#   'amonut': 122,
#   'marketSum': 373},
#  {'itemcode': '354350',
#   'etfTabCode': 4,
#   'itemname': 'HANARO 글로벌럭셔리S&P(합성)',
#   'nowVal': 18160,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.06,
#   'nav': None,
#   'threeMonthEarnRate': 11.8842,
#   'quant': 54301,
#   'amonut': 984,
#   'marketSum': 372},
#  {'itemcode': '385510',
#   'etfTabCode': 2,
#   'itemname': 'KODEX K-신재생에너지액티브',
#   'nowVal': 10305,
#   'risefall': '5',
#   'changeVal': -110,
#   'changeRate': -1.06,
#   'nav': 10340.0,
#   'threeMonthEarnRate': None,
#   'quant': 57584,
#   'amonut': 595,
#   'marketSum': 371},
#  {'itemcode': '122260',
#   'etfTabCode': 6,
#   'itemname': 'KOSEF 통안채1년',
#   'nowVal': 101120,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.02,
#   'nav': 101113.0,
#   'threeMonthEarnRate': -0.0989,
#   'quant': 151738,
#   'amonut': 15342,
#   'marketSum': 364},
#  {'itemcode': '244580',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 바이오',
#   'nowVal': 15455,
#   'risefall': '2',
#   'changeVal': 345,
#   'changeRate': 2.28,
#   'nav': 15555.0,
#   'threeMonthEarnRate': 5.0764,
#   'quant': 212523,
#   'amonut': 3247,
#   'marketSum': 359},
#  {'itemcode': '279530',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 고배당',
#   'nowVal': 10150,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -0.39,
#   'nav': 10163.0,
#   'threeMonthEarnRate': 12.4103,
#   'quant': 43878,
#   'amonut': 445,
#   'marketSum': 355},
#  {'itemcode': '169950',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 중국본토 A50',
#   'nowVal': 23615,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 0.4,
#   'nav': None,
#   'threeMonthEarnRate': 1.4011,
#   'quant': 34636,
#   'amonut': 815,
#   'marketSum': 354},
#  {'itemcode': '099140',
#   'etfTabCode': 4,
#   'itemname': 'KODEX China H',
#   'nowVal': 21755,
#   'risefall': '2',
#   'changeVal': 165,
#   'changeRate': 0.76,
#   'nav': None,
#   'threeMonthEarnRate': -2.7259,
#   'quant': 3762,
#   'amonut': 81,
#   'marketSum': 348},
#  {'itemcode': '252420',
#   'etfTabCode': 3,
#   'itemname': 'KBSTAR 200선물인버스2X',
#   'nowVal': 1870,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 1.36,
#   'nav': 1875.0,
#   'threeMonthEarnRate': -11.7225,
#   'quant': 275714,
#   'amonut': 514,
#   'marketSum': 348},
#  {'itemcode': '326230',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 내수주플러스',
#   'nowVal': 11515,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.09,
#   'nav': 11516.0,
#   'threeMonthEarnRate': 8.0281,
#   'quant': 56341,
#   'amonut': 647,
#   'marketSum': 348},
#  {'itemcode': '139270',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 금융',
#   'nowVal': 7205,
#   'risefall': '5',
#   'changeVal': -100,
#   'changeRate': -1.37,
#   'nav': 7210.0,
#   'threeMonthEarnRate': 9.0949,
#   'quant': 45799,
#   'amonut': 331,
#   'marketSum': 346},
#  {'itemcode': '276970',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국S&P고배당커버드콜(합성 H)',
#   'nowVal': 10330,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.1,
#   'nav': None,
#   'threeMonthEarnRate': 0.8501,
#   'quant': 11088,
#   'amonut': 114,
#   'marketSum': 341},
#  {'itemcode': '387270',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌BBIG액티브',
#   'nowVal': 11025,
#   'risefall': '2',
#   'changeVal': 70,
#   'changeRate': 0.64,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 125837,
#   'amonut': 1386,
#   'marketSum': 340},
#  {'itemcode': '137610',
#   'etfTabCode': 5,
#   'itemname': 'TIGER 농산물선물Enhanced(H)',
#   'nowVal': 6620,
#   'risefall': '2',
#   'changeVal': 330,
#   'changeRate': 5.25,
#   'nav': None,
#   'threeMonthEarnRate': 13.2313,
#   'quant': 155082,
#   'amonut': 1030,
#   'marketSum': 338},
#  {'itemcode': '385600',
#   'etfTabCode': 2,
#   'itemname': '네비게이터 친환경자동차밸류체인액티브',
#   'nowVal': 10840,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 10829.0,
#   'threeMonthEarnRate': None,
#   'quant': 40806,
#   'amonut': 439,
#   'marketSum': 336},
#  {'itemcode': '114470',
#   'etfTabCode': 6,
#   'itemname': 'KOSEF 국고채3년',
#   'nowVal': 111965,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.05,
#   'nav': 111936.0,
#   'threeMonthEarnRate': -0.2274,
#   'quant': 303,
#   'amonut': 33,
#   'marketSum': 336},
#  {'itemcode': '364990',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX게임K-뉴딜',
#   'nowVal': 11580,
#   'risefall': '2',
#   'changeVal': 240,
#   'changeRate': 2.12,
#   'nav': 11576.0,
#   'threeMonthEarnRate': 1.841,
#   'quant': 128196,
#   'amonut': 1488,
#   'marketSum': 336},
#  {'itemcode': '359210',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스피TR',
#   'nowVal': 15215,
#   'risefall': '5',
#   'changeVal': -100,
#   'changeRate': -0.65,
#   'nav': 15217.0,
#   'threeMonthEarnRate': 7.7004,
#   'quant': 74397,
#   'amonut': 1129,
#   'marketSum': 335},
#  {'itemcode': '269540',
#   'etfTabCode': 4,
#   'itemname': 'ARIRANG 미국S&P500(H)',
#   'nowVal': 17580,
#   'risefall': '2',
#   'changeVal': 45,
#   'changeRate': 0.26,
#   'nav': None,
#   'threeMonthEarnRate': 8.2741,
#   'quant': 12762,
#   'amonut': 224,
#   'marketSum': 334},
#  {'itemcode': '203780',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국나스닥바이오',
#   'nowVal': 21385,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.26,
#   'nav': None,
#   'threeMonthEarnRate': 10.3751,
#   'quant': 25920,
#   'amonut': 553,
#   'marketSum': 321},
#  {'itemcode': '138910',
#   'etfTabCode': 5,
#   'itemname': 'KODEX 구리선물(H)',
#   'nowVal': 7820,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.13,
#   'nav': None,
#   'threeMonthEarnRate': 4.8322,
#   'quant': 76223,
#   'amonut': 597,
#   'marketSum': 321},
#  {'itemcode': '292160',
#   'etfTabCode': 1,
#   'itemname': 'TIGER KRX300',
#   'nowVal': 20030,
#   'risefall': '5',
#   'changeVal': -90,
#   'changeRate': -0.45,
#   'nav': 20042.0,
#   'threeMonthEarnRate': 4.8517,
#   'quant': 88,
#   'amonut': 1,
#   'marketSum': 320},
#  {'itemcode': '228790',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 화장품',
# ...
#  {'itemcode': '252720',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 모멘텀밸류',
#   'nowVal': 15565,
#   'risefall': '5',
#   'changeVal': -170,
#   'changeRate': -1.08,
#   'nav': 15555.0,
#   'threeMonthEarnRate': 5.1172,
#   'quant': 43,
#   'amonut': 0,
#   'marketSum': 62},
#  {'itemcode': '342600',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KRX국채선물3년10년스티프너2X',
#   'nowVal': 51885,
#   'risefall': '5',
#   'changeVal': -75,
#   'changeRate': -0.14,
#   'nav': 51912.0,
#   'threeMonthEarnRate': -0.6311,
#   'quant': 42,
#   'amonut': 2,
#   'marketSum': 62},
#  {'itemcode': '215620',
#   'etfTabCode': 2,
#   'itemname': '흥국 S&P코리아로우볼',
#   'nowVal': 12885,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 12823.0,
#   'threeMonthEarnRate': 15.519,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 62},
#  {'itemcode': '295820',
#   'etfTabCode': 1,
#   'itemname': 'ARIRANG 200동일가중',
#   'nowVal': 12335,
#   'risefall': '5',
#   'changeVal': -45,
#   'changeRate': -0.36,
#   'nav': 12332.0,
#   'threeMonthEarnRate': 12.484,
#   'quant': 79,
#   'amonut': 0,
#   'marketSum': 62},
#  {'itemcode': '284990',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200에너지화학',
#   'nowVal': 14000,
#   'risefall': '5',
#   'changeVal': -300,
#   'changeRate': -2.1,
#   'nav': 14007.0,
#   'threeMonthEarnRate': 8.3825,
#   'quant': 6749,
#   'amonut': 95,
#   'marketSum': 62},
#  {'itemcode': '342500',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KRX국채선물3년10년스티프너',
#   'nowVal': 51150,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -0.13,
#   'nav': 51177.0,
#   'threeMonthEarnRate': -0.263,
#   'quant': 42,
#   'amonut': 2,
#   'marketSum': 61},
#  {'itemcode': '157500',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 증권',
#   'nowVal': 4940,
#   'risefall': '5',
#   'changeVal': -70,
#   'changeRate': -1.4,
#   'nav': 4941.0,
#   'threeMonthEarnRate': 10.8897,
#   'quant': 37949,
#   'amonut': 188,
#   'marketSum': 61},
#  {'itemcode': '346000',
#   'etfTabCode': 6,
#   'itemname': 'HANARO KAP초장기국고채',
#   'nowVal': 46030,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.12,
#   'nav': 46140.0,
#   'threeMonthEarnRate': -0.2907,
#   'quant': 320,
#   'amonut': 14,
#   'marketSum': 61},
#  {'itemcode': '250730',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 차이나HSCEI(H)',
#   'nowVal': 12090,
#   'risefall': '5',
#   'changeVal': -170,
#   'changeRate': -1.39,
#   'nav': None,
#   'threeMonthEarnRate': -2.3886,
#   'quant': 6,
#   'amonut': 0,
#   'marketSum': 60},
#  {'itemcode': '176710',
#   'etfTabCode': 6,
#   'itemname': '파워 중기국고채',
#   'nowVal': 100035,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': 0.0,
#   'nav': 100024.0,
#   'threeMonthEarnRate': -0.2045,
#   'quant': 2,
#   'amonut': 0,
#   'marketSum': 60},
#  {'itemcode': '287310',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200경기소비재',
#   'nowVal': 12450,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.08,
#   'nav': 12470.0,
#   'threeMonthEarnRate': 7.1582,
#   'quant': 2012,
#   'amonut': 24,
#   'marketSum': 60},
#  {'itemcode': '342610',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KRX국채선물3년10년플래트너',
#   'nowVal': 49700,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.02,
#   'nav': 49719.0,
#   'threeMonthEarnRate': 0.3735,
#   'quant': 42,
#   'amonut': 2,
#   'marketSum': 60},
#  {'itemcode': '287320',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200산업재',
#   'nowVal': 13480,
#   'risefall': '5',
#   'changeVal': -75,
#   'changeRate': -0.55,
#   'nav': 13485.0,
#   'threeMonthEarnRate': 17.4508,
#   'quant': 515,
#   'amonut': 6,
#   'marketSum': 59},
#  {'itemcode': '213610',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 삼성그룹밸류',
#   'nowVal': 9860,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 9861.0,
#   'threeMonthEarnRate': 6.25,
#   'quant': 14063,
#   'amonut': 138,
#   'marketSum': 59},
#  {'itemcode': '217790',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 가격조정',
#   'nowVal': 26875,
#   'risefall': '2',
#   'changeVal': 130,
#   'changeRate': 0.49,
#   'nav': 26869.0,
#   'threeMonthEarnRate': 2.1425,
#   'quant': 10837,
#   'amonut': 290,
#   'marketSum': 59},
#  {'itemcode': '342620',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR KRX국채선물3년10년플래트너2X',
#   'nowVal': 49020,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.02,
#   'nav': 49042.0,
#   'threeMonthEarnRate': 0.6365,
#   'quant': 91,
#   'amonut': 4,
#   'marketSum': 59},
#  {'itemcode': '302180',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 국채선물10년인버스',
#   'nowVal': 48535,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 48543.0,
#   'threeMonthEarnRate': -0.1954,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 58},
#  {'itemcode': '333980',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG KS퀄리티가중TR',
#   'nowVal': 16485,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.18,
#   'nav': 16485.0,
#   'threeMonthEarnRate': 4.9904,
#   'quant': 28,
#   'amonut': 0,
#   'marketSum': 58},
#  {'itemcode': '275750',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 코스닥150선물인버스',
#   'nowVal': 4595,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.76,
#   'nav': 4594.0,
#   'threeMonthEarnRate': -3.8422,
#   'quant': 14942,
#   'amonut': 68,
#   'marketSum': 57},
#  {'itemcode': '267440',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국장기국채선물(H)',
#   'nowVal': 11465,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.04,
#   'nav': None,
#   'threeMonthEarnRate': 4.7531,
#   'quant': 529,
#   'amonut': 6,
#   'marketSum': 57},
#  {'itemcode': '290080',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200고배당커버드콜ATM',
#   'nowVal': 8160,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.12,
#   'nav': 8140.0,
#   'threeMonthEarnRate': 7.8755,
#   'quant': 136,
#   'amonut': 1,
#   'marketSum': 57},
#  {'itemcode': '280920',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG 주도업종',
#   'nowVal': 12630,
#   'risefall': '5',
#   'changeVal': -160,
#   'changeRate': -1.25,
#   'nav': 12631.0,
#   'threeMonthEarnRate': 8.5369,
#   'quant': 993,
#   'amonut': 12,
#   'marketSum': 57},
#  {'itemcode': '269530',
#   'etfTabCode': 4,
#   'itemname': 'ARIRANG S&P글로벌인프라',
#   'nowVal': 11350,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.49,
#   'nav': None,
#   'threeMonthEarnRate': 1.6651,
#   'quant': 1159,
#   'amonut': 13,
#   'marketSum': 57},
#  {'itemcode': '295000',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 국채선물10년',
#   'nowVal': 55285,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.03,
#   'nav': 55275.0,
#   'threeMonthEarnRate': 0.281,
#   'quant': 133,
#   'amonut': 7,
#   'marketSum': 56},
#  {'itemcode': '380340',
#   'etfTabCode': 2,
#   'itemname': 'KINDEX Fn5G플러스',
#   'nowVal': 9380,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.21,
#   'nav': 9416.0,
#   'threeMonthEarnRate': None,
#   'quant': 2876,
#   'amonut': 26,
#   'marketSum': 56},
#  {'itemcode': '140570',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 수출주',
#   'nowVal': 13920,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -0.39,
#   'nav': 13906.0,
#   'threeMonthEarnRate': 10.2912,
#   'quant': 63,
#   'amonut': 0,
#   'marketSum': 56},
#  {'itemcode': '309210',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG KRX300헬스케어',
#   'nowVal': 13905,
#   'risefall': '2',
#   'changeVal': 220,
#   'changeRate': 1.61,
#   'nav': 13984.0,
#   'threeMonthEarnRate': -1.6529,
#   'quant': 2026,
#   'amonut': 27,
#   'marketSum': 56},
#  {'itemcode': '266550',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG 중형주저변동50',
#   'nowVal': 12215,
#   'risefall': '5',
#   'changeVal': -45,
#   'changeRate': -0.37,
#   'nav': 12218.0,
#   'threeMonthEarnRate': 9.1135,
#   'quant': 80,
#   'amonut': 0,
#   'marketSum': 55},
#  {'itemcode': '261920',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 필리핀MSCI(합성)',
#   'nowVal': 13725,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.18,
#   'nav': None,
#   'threeMonthEarnRate': 4.1825,
#   'quant': 1744,
#   'amonut': 24,
#   'marketSum': 55},
#  {'itemcode': '278420',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG ESG우수기업',
#   'nowVal': 9980,
#   'risefall': '5',
#   'changeVal': -50,
#   'changeRate': -0.5,
#   'nav': 9991.0,
#   'threeMonthEarnRate': 11.7797,
#   'quant': 2474,
#   'amonut': 24,
#   'marketSum': 55},
#  {'itemcode': '295020',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 국채선물10년인버스',
#   'nowVal': 47770,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -0.08,
#   'nav': 47809.0,
#   'threeMonthEarnRate': -0.1462,
#   'quant': 42,
#   'amonut': 2,
#   'marketSum': 54},
#  {'itemcode': '285010',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200중공업',
#   'nowVal': 11800,
#   'risefall': '5',
#   'changeVal': -75,
#   'changeRate': -0.63,
#   'nav': 11833.0,
#   'threeMonthEarnRate': 19.8647,
#   'quant': 1733,
#   'amonut': 20,
#   'marketSum': 54},
#  {'itemcode': '321410',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 멀티에셋하이인컴(H)',
#   'nowVal': 10835,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.05,
#   'nav': None,
#   'threeMonthEarnRate': 3.9846,
#   'quant': 1319,
#   'amonut': 14,
#   'marketSum': 54},
#  {'itemcode': '304670',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국채울트라30년선물인버스(H)',
#   'nowVal': 7560,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': None,
#   'threeMonthEarnRate': -7.0111,
#   'quant': 5489,
#   'amonut': 41,
#   'marketSum': 53},
#  {'itemcode': '269370',
#   'etfTabCode': 4,
#   'itemname': 'TIGER S&P글로벌인프라(합성)',
#   'nowVal': 10500,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.1,
#   'nav': None,
#   'threeMonthEarnRate': 1.9337,
#   'quant': 316,
#   'amonut': 3,
#   'marketSum': 53},
#  {'itemcode': '220130',
#   'etfTabCode': 4,
#   'itemname': 'SMART 중국본토 중소형 CSI500(합성 H)',
#   'nowVal': 5690,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.09,
#   'nav': None,
#   'threeMonthEarnRate': 9.0124,
#   'quant': 5319,
#   'amonut': 30,
#   'marketSum': 51},
#  {'itemcode': '292770',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 국채선물3년인버스',
#   'nowVal': 49925,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 49944.0,
#   'threeMonthEarnRate': 0.3215,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 51},
#  {'itemcode': '371870',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 차이나항셍테크',
#   'nowVal': 10180,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.15,
#   'nav': None,
#   'threeMonthEarnRate': -0.926,
#   'quant': 4594,
#   'amonut': 46,
#   'marketSum': 51},
#  {'itemcode': '261270',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 미국달러선물인버스',
#   'nowVal': 10110,
#   'risefall': '5',
#   'changeVal': -50,
#   'changeRate': -0.49,
#   'nav': 10109.0,
#   'threeMonthEarnRate': 0.594,
#   'quant': 1287,
#   'amonut': 13,
#   'marketSum': 51},
#  {'itemcode': '261260',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 미국달러선물인버스2X',
#   'nowVal': 9675,
#   'risefall': '5',
#   'changeVal': -115,
#   'changeRate': -1.17,
#   'nav': 9676.0,
#   'threeMonthEarnRate': 0.8758,
#   'quant': 33102,
#   'amonut': 320,
#   'marketSum': 50},
#  {'itemcode': '285020',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200철강소재',
#   'nowVal': 9675,
#   'risefall': '5',
#   'changeVal': -65,
#   'changeRate': -0.67,
#   'nav': 9670.0,
#   'threeMonthEarnRate': 15.8971,
#   'quant': 4287,
#   'amonut': 41,
#   'marketSum': 50},
#  {'itemcode': '299080',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX 국채선물3년인버스',
#   'nowVal': 99795,
#   'risefall': '5',
#   'changeVal': -45,
#   'changeRate': -0.05,
#   'nav': 99870.0,
#   'threeMonthEarnRate': 0.377,
#   'quant': 1,
#   'amonut': 0,
#   'marketSum': 50},
#  {'itemcode': '291680',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 차이나H선물인버스(H)',
#   'nowVal': 9585,
#   'risefall': '2',
#   'changeVal': 80,
#   'changeRate': 0.84,
#   'nav': None,
#   'threeMonthEarnRate': 1.8211,
#   'quant': 104,
#   'amonut': 0,
#   'marketSum': 48},
#  {'itemcode': '299070',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX 국채선물10년인버스',
#   'nowVal': 95685,
#   'risefall': '5',
#   'changeVal': -90,
#   'changeRate': -0.09,
#   'nav': 95791.0,
#   'threeMonthEarnRate': -0.0209,
#   'quant': 1,
#   'amonut': 0,
#   'marketSum': 48},
#  {'itemcode': '139310',
#   'etfTabCode': 5,
#   'itemname': 'TIGER 금속선물(H)',
#   'nowVal': 6825,
#   'risefall': '5',
#   'changeVal': -50,
#   'changeRate': -0.73,
#   'nav': None,
#   'threeMonthEarnRate': 10.9765,
#   'quant': 12143,
#   'amonut': 83,
#   'marketSum': 48},
#  {'itemcode': '211260',
#   'etfTabCode': 2,
#   'itemname': 'KINDEX 배당성장',
#   'nowVal': 39480,
#   'risefall': '5',
#   'changeVal': -230,
#   'changeRate': -0.58,
#   'nav': 39421.0,
#   'threeMonthEarnRate': 7.7056,
#   'quant': 94,
#   'amonut': 3,
#   'marketSum': 47},
#  {'itemcode': '287330',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200생활소비재',
#   'nowVal': 9315,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -0.59,
#   'nav': 9322.0,
#   'threeMonthEarnRate': 4.4476,
#   'quant': 15830,
#   'amonut': 147,
#   'marketSum': 47},
#  {'itemcode': '296710',
#   'etfTabCode': 2,
#   'itemname': 'KODEX FnKorea50',
#   'nowVal': 11535,
#   'risefall': '5',
#   'changeVal': -50,
#   'changeRate': -0.43,
#   'nav': 11532.0,
#   'threeMonthEarnRate': 8.1295,
#   'quant': 37,
#   'amonut': 0,
#   'marketSum': 46},
#  {'itemcode': '284980',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200금융',
#   'nowVal': 9110,
#   'risefall': '5',
#   'changeVal': -120,
#   'changeRate': -1.3,
#   'nav': 9117.0,
#   'threeMonthEarnRate': 8.6137,
#   'quant': 5137,
#   'amonut': 46,
#   'marketSum': 46},
#  {'itemcode': '301410',
#   'etfTabCode': 3,
#   'itemname': 'ARIRANG 코스닥150선물인버스',
#   'nowVal': 6920,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.43,
#   'nav': 6889.0,
#   'threeMonthEarnRate': -3.9392,
#   'quant': 7508,
#   'amonut': 52,
#   'marketSum': 45},
#  {'itemcode': '280940',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 골드선물인버스(H)',
#   'nowVal': 7350,
#   'risefall': '5',
#   'changeVal': -50,
#   'changeRate': -0.68,
#   'nav': None,
#   'threeMonthEarnRate': -3.078,
#   'quant': 2427,
#   'amonut': 17,
#   'marketSum': 44},
#  {'itemcode': '227560',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 생활소비재',
#   'nowVal': 12230,
#   'risefall': '5',
#   'changeVal': -90,
#   'changeRate': -0.73,
#   'nav': 12234.0,
#   'threeMonthEarnRate': 4.3183,
#   'quant': 2351,
#   'amonut': 28,
#   'marketSum': 44},
#  {'itemcode': '291620',
#   'etfTabCode': 3,
#   'itemname': 'KOSEF 코스닥150선물인버스',
#   'nowVal': 7920,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -0.69,
#   'nav': 7902.0,
#   'threeMonthEarnRate': -3.7998,
#   'quant': 1615,
#   'amonut': 12,
#   'marketSum': 42},
#  {'itemcode': '267450',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국장기국채선물인버스(H)',
#   'nowVal': 8100,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': -0.06,
#   'nav': None,
#   'threeMonthEarnRate': -5.3707,
#   'quant': 2165,
#   'amonut': 17,
#   'marketSum': 41},
#  {'itemcode': '253240',
#   'etfTabCode': 3,
#   'itemname': 'KOSEF 200선물인버스',
#   'nowVal': 4805,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.63,
#   'nav': 4795.0,
#   'threeMonthEarnRate': -5.6325,
#   'quant': 13337,
#   'amonut': 63,
#   'marketSum': 39},
#  {'itemcode': '291660',
#   'etfTabCode': 4,
#   'itemname': 'KODEX China H선물인버스(H)',
#   'nowVal': 9680,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.1,
#   'nav': None,
#   'threeMonthEarnRate': 1.7894,
#   'quant': 31,
#   'amonut': 0,
#   'marketSum': 39},
#  {'itemcode': '217770',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 원유선물인버스(H)',
#   'nowVal': 5850,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.51,
#   'nav': None,
#   'threeMonthEarnRate': -17.7623,
#   'quant': 3679,
#   'amonut': 21,
#   'marketSum': 38},
#  {'itemcode': '267500',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#   'nowVal': 6290,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.16,
#   'nav': None,
#   'threeMonthEarnRate': -10.4776,
#   'quant': 7052,
#   'amonut': 44,
#   'marketSum': 35},
#  {'itemcode': '291890',
#   'etfTabCode': 4,
#   'itemname': 'KODEX MSCI EM선물(H)',
#   'nowVal': 11000,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.32,
#   'nav': None,
#   'threeMonthEarnRate': 4.746,
#   'quant': 1220,
#   'amonut': 13,
#   'marketSum': 33},
#  {'itemcode': '309170',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG KRX300IT',
#   'nowVal': 19400,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 19512.0,
#   'threeMonthEarnRate': -0.3391,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 27},
#  {'itemcode': '306540',
#   'etfTabCode': 6,
#   'itemname': 'HANARO 단기통안채',
#   'nowVal': 103070,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 103070.0,
#   'threeMonthEarnRate': 0.0631,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 23},
#  {'itemcode': '334700',
#   'etfTabCode': 5,
#   'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#   'nowVal': 4355,
#   'risefall': '5',
#   'changeVal': -105,
#   'changeRate': -2.35,
#   'nav': None,
#   'threeMonthEarnRate': -7.9464,
#   'quant': 3768,
#   'amonut': 16,
#   'marketSum': 22}]

# %%
df = pd.DataFrame(etfItemList)
df
# Out:
#     itemcode  etfTabCode                    itemname  nowVal risefall  \
# 0     069500           1                   KODEX 200   43640        5
# 1     153130           6                  KODEX 단기채권  102775        3
# 2     252670           3            KODEX 200선물인버스2X    1875        2
# 3     102110           1                   TIGER 200   43665        5
# 4     102780           2                  KODEX 삼성그룹   10365        2
# ..       ...         ...                         ...     ...      ...
# 480   267500           4  KBSTAR 미국장기국채선물인버스2X(합성 H)    6290        2
# 481   291890           4          KODEX MSCI EM선물(H)   11000        5
# 482   309170           2            ARIRANG KRX300IT   19400        3
# 483   306540           6                HANARO 단기통안채  103070        3
# 484   334700           5          KBSTAR 팔라듐선물인버스(H)    4355        5
#
#      changeVal  changeRate       nav  threeMonthEarnRate      quant  amonut  \
# 0         -255       -0.58   43745.0              5.3977    3117261  136125
# 1            0        0.00  102779.0              0.0048       2394     246
# 2           25        1.35    1876.0            -11.4833  105541555  197354
# 3         -250       -0.57   43771.0              5.3420     608535   26593
# 4           65        0.63   10378.0              4.1140     321065    3322
# ..         ...         ...       ...                 ...        ...     ...
# 480         10        0.16       NaN            -10.4776       7052      44
# 481        -35       -0.32       NaN              4.7460       1220      13
# 482          0        0.00   19512.0             -0.3391          0       0
# 483          0        0.00  103070.0              0.0631          0       0
# 484       -105       -2.35       NaN             -7.9464       3768      16
#
#      marketSum
# 0        40782
# 1        24889
# 2        24881
# 3        21767
# 4        18958
# ..         ...
# 480         35
# 481         33
# 482         27
# 483         23
# 484         22
#
# [485 rows x 12 columns]

# %%
df.head()
# Out:
#   itemcode  etfTabCode          itemname  nowVal risefall  changeVal  \
# 0   069500           1         KODEX 200   43640        5       -255
# 1   153130           6        KODEX 단기채권  102775        3          0
# 2   252670           3  KODEX 200선물인버스2X    1875        2         25
# 3   102110           1         TIGER 200   43665        5       -250
# 4   102780           2        KODEX 삼성그룹   10365        2         65
#
#    changeRate       nav  threeMonthEarnRate      quant  amonut  marketSum
# 0       -0.58   43745.0              5.3977    3117261  136125      40782
# 1        0.00  102779.0              0.0048       2394     246      24889
# 2        1.35    1876.0            -11.4833  105541555  197354      24881
# 3       -0.57   43771.0              5.3420     608535   26593      21767
# 4        0.63   10378.0              4.1140     321065    3322      18958

# %%
df.tail()
# Out:
#     itemcode  etfTabCode                    itemname  nowVal risefall  \
# 480   267500           4  KBSTAR 미국장기국채선물인버스2X(합성 H)    6290        2
# 481   291890           4          KODEX MSCI EM선물(H)   11000        5
# 482   309170           2            ARIRANG KRX300IT   19400        3
# 483   306540           6                HANARO 단기통안채  103070        3
# 484   334700           5          KBSTAR 팔라듐선물인버스(H)    4355        5
#
#      changeVal  changeRate       nav  threeMonthEarnRate  quant  amonut  \
# 480         10        0.16       NaN            -10.4776   7052      44
# 481        -35       -0.32       NaN              4.7460   1220      13
# 482          0        0.00   19512.0             -0.3391      0       0
# 483          0        0.00  103070.0              0.0631      0       0
# 484       -105       -2.35       NaN             -7.9464   3768      16
#
#      marketSum
# 480         35
# 481         33
# 482         27
# 483         23
# 484         22

# %%
import datetime

today =datetime.datetime.today().strftime("%y-%m-%d")
today
# Out:
# '21-07-01'

# %%
file_name = f"etf-{today}.csv"
file_name
# Out:
# 'etf-21-07-01.csv'

# %%
df.to_csv(file_name, index=False)

# %%
pd.read_csv(file_name, dtype = { 'itemcode' : np.object})
# Out:
#     itemcode  etfTabCode                    itemname  nowVal  risefall  \
# 0     069500           1                   KODEX 200   43640         5
# 1     153130           6                  KODEX 단기채권  102775         3
# 2     252670           3            KODEX 200선물인버스2X    1875         2
# 3     102110           1                   TIGER 200   43665         5
# 4     102780           2                  KODEX 삼성그룹   10365         2
# ..       ...         ...                         ...     ...       ...
# 480   267500           4  KBSTAR 미국장기국채선물인버스2X(합성 H)    6290         2
# 481   291890           4          KODEX MSCI EM선물(H)   11000         5
# 482   309170           2            ARIRANG KRX300IT   19400         3
# 483   306540           6                HANARO 단기통안채  103070         3
# 484   334700           5          KBSTAR 팔라듐선물인버스(H)    4355         5
#
#      changeVal  changeRate       nav  threeMonthEarnRate      quant  amonut  \
# 0         -255       -0.58   43745.0              5.3977    3117261  136125
# 1            0        0.00  102779.0              0.0048       2394     246
# 2           25        1.35    1876.0            -11.4833  105541555  197354
# 3         -250       -0.57   43771.0              5.3420     608535   26593
# 4           65        0.63   10378.0              4.1140     321065    3322
# ..         ...         ...       ...                 ...        ...     ...
# 480         10        0.16       NaN            -10.4776       7052      44
# 481        -35       -0.32       NaN              4.7460       1220      13
# 482          0        0.00   19512.0             -0.3391          0       0
# 483          0        0.00  103070.0              0.0631          0       0
# 484       -105       -2.35       NaN             -7.9464       3768      16
#
#      marketSum
# 0        40782
# 1        24889
# 2        24881
# 3        21767
# 4        18958
# ..         ...
# 480         35
# 481         33
# 482         27
# 483         23
# 484         22
#
# [485 rows x 12 columns]
